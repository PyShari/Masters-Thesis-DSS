# %% [markdown]
# # 00 — Data Preparation & Cleaning

# %% [markdown]
# ## 1. Overview

# %% [markdown]
# This notebook performs the initial cleaning of the raw dataset, including:
# - loading raw data
# - applying cleaning rules
# - filtering invalid or missing target values
# - splitting the dataset into regimes
# - saving cleaned outputs for downstream notebooks
#
# This ensures that all subsequent analysis (EDA, modeling, SHAP) uses consistent, reproducible inputs.

# %%
import sys
import os

# Determine the project root (one level above the notebook directory)
project_root = os.path.abspath("..")

# Add project root to Python path so modules in /src can be imported
if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added:", project_root)

# Build data directory path
data_dir = os.path.join(project_root, "data")
print("Data directory:", data_dir)
# Out:
# Project root added: C:\Users\shari\OneDrive\MSc Data Science and Society\Thesis_DSS_2026
# Data directory: C:\Users\shari\OneDrive\MSc Data Science and Society\Thesis_DSS_2026\data

# %% [markdown]
# ## 2. Imports

# %%
# ============================================================
# IMPORTS
# ------------------------------------------------------------
# This section loads all external libraries and internal modules
# required for the data-loading, cleaning, preprocessing, and
# regime-splitting pipeline.
# ============================================================

# --- Core scientific Python libraries ---
import pandas as pd      # Data manipulation, tabular operations, DataFrame handling
import numpy as np       # Numerical operations, arrays, vectorized computations


# --- Data loading utilities ---
from src.data_loading import load_liss_datasets
# load_liss_datasets: reads multiple LISS .dta files into a dictionary of DataFrames


# --- Preprocessing utilities ---
from src.data_cleaning import process_dataset, merge_datasets
# process_dataset: applies year-specific preprocessing rules to each dataset
# merge_datasets: vertically concatenates all yearly datasets into one DataFrame


# --- Target filtering utilities ---
from src.target_filtering import drop_missing_target, drop_missing_target_for_regimes
# drop_missing_target: removes rows with missing target variable
# drop_missing_target_for_regimes: applies the same filtering separately to each regime


# --- Column-level cleaning functions ---
from src.column_cleaning import (
    normalize_all_text,                    # Standardizes text columns (lowercase, strip whitespace)
    replace_string_nan,                    # Converts string-based "nan" values into actual NaN
    replace_dont_know,                     # Replaces "don't know" responses with NaN
    apply_verbal_scales,                   # Converts verbal response scales into numeric equivalents
    convert_binary,                        # Converts yes/no or similar binary fields into 0/1
    convert_numeric_like,                  # Converts numeric-like strings into numeric dtype
    convert_ordinal_scales,                # Converts ordinal categories into ordered numeric scales
    drop_columns,                          # Drops a predefined list of columns
    drop_empty_columns,                    # Removes columns that contain only missing values
    drop_pension_exit_and_text_columns,    # Removes pension-related, exit-related, and free-text columns
    drop_contract_hours_and_income         # Removes variables that would leak target information
)


# --- Column override rules (manual corrections) ---
from src.column_overrides import (
    clean_selected_columns,                # Applies custom cleaning rules to specific columns
    clean_remaining_columns,               # Applies fallback cleaning rules to all other columns
    clean_dataset,                         # Full override cleaning pipeline for a dataset
    normalize_regime                       # Ensures regime labels are standardized
)


# --- Full cleaning pipeline wrapper ---
from src.cleaning_pipeline import clean_full_dataset
# clean_full_dataset: orchestrates all cleaning steps into one unified pipeline


# --- Regime splitting utilities ---
from src.regime_split import (
    filter_by_conditions,                  # Filters dataset to working individuals only
    split_by_regime,                       # Splits dataset into economic regimes (A, B, C)
    summarize_regimes                      # Prints summary statistics for each regime
)

# %% [markdown]
# ## 3. Load raw datasets

# %%
# Folder containing all raw LISS .dta files
folder_path = (
    "C:/Users/shari/OneDrive/MSc Data Science and Society/Thesis_DSS_2026/data"
)

# Mapping between survey year and filename
file_year_map = {
    2008: "cw08a_EN_1.1p.dta",
    2009: "cw09b_EN_3.0p.dta",
    2010: "cw10c_EN_1.0p.dta",
    2011: "cw11d_EN_1.0p.dta",
    2012: "cw12e_EN_1.0p.dta",
    2013: "cw13f_EN_1.0p.dta",
    2014: "cw14g_EN_1.0p.dta",
    2015: "cw15h_EN_2.0p.dta",
    2016: "cw16i_EN_2.0p.dta",
    2017: "cw17j_EN_2.0p.dta",
    2018: "cw18k_EN_2.0p.dta",
    2019: "cw19l_EN_3.0p.dta",
    2020: "cw20m_EN_1.0p.dta",
    2021: "cw21n_EN_1.0p.dta",
    2022: "cw22o_EN_1.0p.dta",
    2023: "cw23p_EN_1.0p.dta",
    2024: "cw24q_EN_1.0p.dta"
}

# Load Raw Datasets
datasets = load_liss_datasets(folder_path, file_year_map)
print(f"Loaded {len(datasets)} datasets.")

# Dictionary to store cleaned versions of each year
cleaned = {}

# Apply year-specific preprocessing to each dataset
for year, df in datasets.items():
    cleaned[year] = process_dataset(df, year)
# Out:
# [OK] Loaded cw08a_EN_1.1p.dta for year 2008 (rows=6951)
# [OK] Loaded cw09b_EN_3.0p.dta for year 2009 (rows=5701)
# [OK] Loaded cw10c_EN_1.0p.dta for year 2010 (rows=6366)
# [OK] Loaded cw11d_EN_1.0p.dta for year 2011 (rows=5358)
# [OK] Loaded cw12e_EN_1.0p.dta for year 2012 (rows=6013)
# [OK] Loaded cw13f_EN_1.0p.dta for year 2013 (rows=5585)
# [OK] Loaded cw14g_EN_1.0p.dta for year 2014 (rows=6570)
# [OK] Loaded cw15h_EN_2.0p.dta for year 2015 (rows=6237)
# [OK] Loaded cw16i_EN_2.0p.dta for year 2016 (rows=5832)
# [OK] Loaded cw17j_EN_2.0p.dta for year 2017 (rows=5926)
# [OK] Loaded cw18k_EN_2.0p.dta for year 2018 (rows=5832)
# [OK] Loaded cw19l_EN_3.0p.dta for year 2019 (rows=5210)
# [OK] Loaded cw20m_EN_1.0p.dta for year 2020 (rows=5646)
# [OK] Loaded cw21n_EN_1.0p.dta for year 2021 (rows=5478)
# [OK] Loaded cw22o_EN_1.0p.dta for year 2022 (rows=5775)
# [OK] Loaded cw23p_EN_1.0p.dta for year 2023 (rows=5139)
# [OK] Loaded cw24q_EN_1.0p.dta for year 2024 (rows=5792)
# Loaded 17 datasets.

# %% [markdown]
# ## 4. Merge dataset

# %%
# Merge all yearly datasets into one combined DataFrame
merged_df = merge_datasets(cleaned)

print("Final merged_df shape:", merged_df.shape)
print(merged_df["year"].value_counts().sort_index())

# Create a working copy
df_clean = merged_df.copy()
# Out:
# Final merged_df shape: (99411, 610)
# year
# 2008    6951
# 2009    5701
# 2010    6366
# 2011    5358
# 2012    6013
# 2013    5585
# 2014    6570
# 2015    6237
# 2016    5832
# 2017    5926
# 2018    5832
# 2019    5210
# 2020    5646
# 2021    5478
# 2022    5775
# 2023    5139
# 2024    5792
# Name: count, dtype: Int64

# %% [markdown]
# ## 5. Apply cleaning functions

# %%
# Remove predefined irrelevant r problematic  columns
# Drop predefined columns
cols_to_remove = [
    '_encr', 'se_encr', '_m',
    '000', '002', '505', '504', '503', '502', '501',
    '500', '499', '498', '497', '496', '525', 
    
]
df_clean, removed_step1 = drop_columns(df_clean, cols_to_remove)
print("Removed Step 1:", removed_step1)
print("Shape:", df_clean.shape)

# Drop fully empty columns
df_clean, removed_step2 = drop_empty_columns(df_clean)
print("Removed Step 2:", removed_step2)
print("Shape:", df_clean.shape)

# Drop pension, exit, and text columns
df_clean, removed_step3 = drop_pension_exit_and_text_columns(df_clean)
print("Removed Step 3:", removed_step3)
print("Shape:", df_clean.shape)

# Drop contract hours and income variables
df_clean, removed_step4 = drop_contract_hours_and_income(df_clean)
print("Removed Step 4:", removed_step4)
print("Shape:", df_clean.shape)

# Normalize all other text columns
df_clean = normalize_all_text(df_clean)
# Out:
# Removed Step 1: ['_encr', 'se_encr', '_m', '000', '002', '496', '497', '498', '499', '500', '501', '502', '503', '504', '505', '525']
# Shape: (99411, 594)
# Removed Step 2: []
# Shape: (99411, 594)
# Removed Step 3: ['099', '146', '147', '148', '149', '150', '151', '152', '153', '154', '155', '156', '157', '158', '159', '160', '161', '162', '163', '164', '165', '166', '167', '168', '169', '170', '171', '172', '173', '174', '175', '176', '177', '178', '179', '180', '181', '182', '183', '184', '185', '186', '187', '188', '189', '190', '191', '192', '193', '194', '195', '196', '197', '198', '199', '200', '201', '202', '203', '204', '205', '206', '207', '208', '209', '210', '211', '212', '213', '214', '215', '216', '217', '218', '219', '220', '221', '222', '223', '224', '225', '226', '227', '228', '229', '230', '231', '232', '233', '234', '235', '236', '237', '238', '239', '240', '241', '242', '243', '244', '245', '246', '247', '248', '249', '250', '251', '252', '253', '254', '255', '256', '257', '258', '259', '260', '261', '262', '263', '264', '265', '266', '267', '268', '269', '270', '271', '272', '273', '274', '275', '276', '277', '278', '279', '280', '281', '282', '283', '284', '285', '286', '287', '290', '291', '292', '293', '294', '295', '296', '297', '298', '299', '300', '301', '302', '303', '304', '305', '306', '307', '224', '225', '317', '165', '160', '164', '156', '152', '148', '112', '082', '085', '071', '065', '058', '054', '048', '041', '037', '029', '010', '007', '522', '523', '126']
# Shape: (99411, 416)
# Removed Step 4: ['576', '577', '578', '121', '380']
# Shape: (99411, 411)

# %%
# identify all columns that are object/string type
cat_cols = df_clean.select_dtypes(include=['object']).columns

# list the unique values for each categorical column
for col in cat_cols:
    print(f"\nColumn: {col}")
    print(df_clean[col].unique())
# Out:
# Column: 051
# ['' 'studiebeurs' 'gratis, omdat ik een student ben'
#  'farmaceutische industrie' 'school en ouders'
#  '(sponsor )texas instruments' 'reiskosten examens: zelf, studie: ouders'
#  'fnv bondgenoten' 'door uwv rechstreeks' 'school' 'reintegratie bureau'
#  'overheidsgeld' 'geen idee' 'door de fabrikant' 'hengelsport organisatie'
#  'via stichtingen' 'het rijk' 'gratis aangeboden door politie'
#  'brancheorganisatie' 'door school'
#  'europees sociaal fonds en lto nederland'
#  'ik volgde al een studie aan een andere instelling dus ben ik vrijgesteld.'
#  'voor het grootste deel door de overheid' 'branche -organisatie'
#  'collegegeld werd voor een groot deel vergoed door de overheid. rest heb ikzelf b'
#  'uwv' 'gaat jullie niks aan' 'door de overheid' 'geen kosten verbonden'
#  'kostte niets.' 'via uwv en rbo reintegratietraject'
#  '? waarschijnlijk vanuit subsidie gemeente den haag'
#  'subsidie door overheid' 'via administratiekanttor van mijn man'
#  'door de parochie' 'gesponsord' 'door de universiteit'
#  'door de instantie die de cursus verzorgde' 'samenwerkingsverband'
#  'metaal nijverheid' 'het pensioenfonds' 'onderdeel van mijn opleiding'
#  'weet ik niet' 'overheid'
#  'ik was bezig met roc school. zo, gemeente betaald voor cursus. maar ries kost is'
#  'sponsor' 'toeleverancier' 'industrie' 'het kostte mij mijn vrije tijd'
#  'naar vorige werkgever' 'overheid via branche organisatie'
#  'visio  blinden begeleidings opleidingen' 'mijn echtgenoot'
#  'aangeboden door de hogeschool utrecht'
#  'sociale dienst en een deel moest ik betalen' 'basisschool' 'door vamex'
#  'door de politie'
#  'grotendeels met subsidie overheid (vanwege gekozen richting onderwijs)'
#  'werd betaald door de coöperatie waar ik lid van ben'
#  'vorige werkgever (onderdeel afkkopsom)'
#  'door de gemeente omdat ik, naast mijn werk, ook een vrijwilligersfunctie bekleed'
#  'door niemand' 'cursus word door collega gegeven'
#  'farmacetische industrie' 'via de universiteit van leiden'
#  'pensioenfonds' 'vrijwilligersorganisatie'
#  'via een buurthuis met subsidie' 'werkgever en gemeente'
#  'door de branche-organisatie zelf' 'geen kosten aan verbonden'
#  'wanneer je een hbo opleiding volgt, wordt dit door school betaald'
#  'partner / echtgenoot' 'het uitzendbureau betaalt de opleiding'
#  'het is zelfstudie!' 'leverancier van de nieuwe producten'
#  'firma die de cursus geeft' 'een sponsor (texas instruments)'
#  'deels gemente en deels ik zelfts'
#  'via het ikstartsmart project van de kamer van koophandel in combinatie met de ge'
#  'door leverancier' 'het kerkbestuur' 'organisatie hengelsport'
#  'deels ikzelf ,deels de regering' 'deelname pilot, subsidie vws'
#  'vereniging waar ik de penningmeester van ben'
#  'informatie beheergroep/ tegemoetkoming leraren' 'door de maatschap'
#  'de branche-organisatie betaalde omdat ik geslaagd ben'
#  'stichting kinderopvang' 'satellietprovider' 'gastouderbureau'
#  'door een collega gegeven' 'lerarenbeus' 'door de school'
#  'het is gratis bij het fnv' 'lerarenbeurs overheid' 'door lidmaatschap'
#  'firma braun' 'door provincie' 'zitten geen kosten aan'
#  'de plaatselijke ehbo vereniging' 'ziektekostenverzekering'
#  'eigen onderneming' 'subsidie' 'door de maatschap waar ik maat van ben'
#  'ik ben zelf eigenaar' 'door slachtofferhulp nederland' 'zelf'
#  'weet nog niet' 'werkgever/overheid' 'gratis aanbod van stadsdeel'
#  'via oppasorganisatie' 'lerarenbeurs'
#  'landelijke regeling - versterken voorschoolse voorzieningen'
#  'het is een interne cursus' 'vertel ik niet' 'geen' 'voetbalvereniging'
#  'bronlaak oploo' 'leverancier' 'subsidie c3' 'gratis'
#  'ik ben zelfstandig dus betaal zelf' 'kostenloos'
#  'werkgever/metaalnijverheid' 'studietegemoetkoming'
#  'mijn ouders en ik zelf' 'gemeente ( smd )' 'vai eigen bedrijf'
#  'gemeente dierenwelzijn en dierenambulance' 'staatsbosbeheer' 'in natura'
#  'vrijwilliger organisatie' 'overheid door subsidie' 'geen kosten'
#  'als introducé, dus geen kosten' 'mijzelf' 'aequor' 'rijksoverheid' 'uaf'
#  'gratis aanbod' 'st.bedrijfspensioenfonds' 'was gratis' 'instantie'
#  'mijn bedrijf' '?' 'cursus was gratis betaald door de uitgeverij'
#  'door c3 mobiliteitscentrum' 'ik ben zelfstandig dus ikzelf'
#  "'werkgever' vrijwilligerswerk" 'ikzelf als werkgever' 'vanuit knvb'
#  'cursus gewonnen bij prijsvraag' 'via een adviesraad' 'humanitas'
#  'door de bond (knkv)' 'ouders en ik zelf gedeelte' 'fnvbouw'
#  'gratis online cursus' 'vorige werkgever' 'door de brancheorganisatie'
#  'zorgverzekering' 'ik ben zelfstandig' 'ikzelf en 1 ouder'
#  'werkgever, europese subsidie en prive' 'de cursus was gratis'
#  'schoonvader' 'google subsidieert deze cursus' 'leverancier producten'
#  'door vrijwilligersorganisatie'
#  'door de maatschap waar ik deel van uitmaak' 'nvt gratis'
#  'zij-instroombeurs' 'stichting' 'oc en w' 'via werkgever'
#  'ned. cva vereniging zh' 'als prijs gewonnen'
#  'via vrijwlilligersorganisatie' 'de cursus is kosteloos'
#  'bureau voor kinderopvang' 'uitgeverij zelf'
#  'deels zelf, deels ouders, geen studiebeurs'
#  'door de overheid! lerarenbeurs.' 'pensioenfonds waar ik dnr/vo lid ben'
#  'doot mijzelf, maar ben zelf ondernemer' 'oud werkgever' 'pin' 'via sboh'
#  'ikzelf/loopbaantraject' 'oud-werkgever' 'sswt'
#  'door de landelijke organisatie schuldhulpmaatjr'
#  'door stichting sensoor noord brabant' 'maatschapskosten'
#  'fabrikant van het product' 'studie financiering'
#  'als praktijkhouder heb ik de cursus in principe zelf betaald, maar onder de noemer van de praktijk'
#  'door de werkgever' 'nvt' 'onder werktijd' 'door pensioenfonds'
#  'jeugdzorgbudget van de gemeente' 'door vluchtelingenwerk'
#  'organisatie heeft het voorgeschiet' 'ocw steunpunt cultuur'
#  'opleiding: de duitse staat, reiskosten: ikzelf' 'via uitzendbureau'
#  'door de vereniging' 'door de overheid: lerarenbeurs'
#  'door bewonersonderneming waar buurthuis ondervalt' 'nwo/cw'
#  'vrijwilligerswerk' 'financiering'
#  'vorige werkgever heeft alles betaald zodat hij onder mijn diploma reviews kan declareren, ik zelf de reiskosten'
#  'via gastouderbureau' 'door de branche-organisatie'
#  'een ervaring collega gaf ons les als het niet druk was op de afdeling'
#  'het was een gratis cursus'
#  'ik ben zelfst. ondernemer en bepaal dus zelf van de zakelijke rekening'
#  'de gemeente die mij inhuurt heeft de cursus betaald' 'maatschap kosten'
#  'vriend' 'ministerie venj' 'outplacementkosten en ikzelf'
#  'vrijwilligers organisatie ciz twente' 'mijn partner'
#  'deels zorgverzekering, deels ik' 'vrijwilligersorganisatie vwn'
#  'het was een gratis cursus (mooc)' 'door brancheorganisatie'
#  'door mezelf en een deel door het uwv' 'door mijn vrijwilligerswerk'
#  'muiswerk betaalde. koste ons niets'
#  'door organisatie die vrijwilligers ccordineert' 'cursus was gratis'
#  'kosten maatschap' 'oma' 'niet via internet, app'
#  'overheid: lerarenbeurs.' 'cnv intern' 'door de stichting'
#  'via branche organisatie' 'stichting sensoor' 'ocenw' 'zorginsteling'
#  'maatschaps kosten' 'door een goede vriend'
#  'het is een gratis cursus op codecademy' 'onstlagvergoeding'
#  'ik ben zelfstandige, kosten zijn betaald uit het eigen bedrijf, dus eigenlijk van mijzelf'
#  'deels zelf en deels werkgever'
#  'vorige werkgever i.v.m. collectief ontslag' '*****' 'n.v.t.'
#  'veiligheidsregio/gemeente' 'door minder salaris te krijgen'
#  'opdrachtgever heeft training bekostigd' 'gemeente'
#  'hoort bij de programma'
#  'aangezien ik het certificaat nog niet heb behaald is dit nog niet van toepassing'
#  'mijn zzp bedrijf' 'rekening'
#  'het bestuur van de oud-medewerkers vereniging' 'bibliotheek abonnement'
#  'ik ben zelfstandig, de vof betaalt de cursus'
#  'door het pensioenfonds horeca&catering' 'verzekering' 'oude werkgever'
#  'toekomstige werkgever' 'belangenorganisatie'
#  'omscholingstraject wordt betaald door microsoft, ik ben niet bij hen indienst maar een derde partij zal bemiddelen naar een baan.'
#  'bko cursussen zijn gratis voor medewerkers van de universiteit.'
#  'ikzelf en mijn ouders' 'pensioenfonds, reiskosten zelf'
#  'ik ontvang salaris' 'de ggz-instelling die de cursus ook organiseerde'
#  'geen kosten een webinar'
#  're-integratiebureau ingehuurd door participatiefonds' 'door de club'
#  'zaak' 'vrij cursus' nan]
#
# Column: 068
# ['' 'was gratis' 'industrie' 'vakbond' 'deels zelf en deel visio leiden'
#  'voor aantal studenten gratis, vanwege bijdrage van de pabo in de organisatie'
#  'hengelsport organisatie' 'overheid'
#  'cursus gegeven door de hogeschool in ruil voor het ontvangen van stagiares van d'
#  'mijn ouders en ik zelf deel van het geld krijg je terug'
#  'aangeboden door de inwa' 'branche organisatie' 'lening bij de bank'
#  'landwinkel coöperatie'
#  'via de gelden uit de financiëring van een (rugzak)leerling met autisme.'
#  'ik volgde nog een studie aan een andere instelling dus ben ik vrijgesteld.'
#  'ik hoef slechts één maal collegegeld te betalen' 'geen'
#  'aangeboden door de cursusaanbieder' 'gaat jullie niks aan'
#  'aangeboden via universiteit' 'zit bij in' 'nvt' 'internet cursus'
#  'verloskundigenpraktijk waar ik deel van uit maak.'
#  'deel zelf , deel gemeente' 'de leverancier' 'n.v.t.' 'nato'
#  'toeleverancier' 'mijn vorige werkgever' 'visio leiden'
#  'farmaceutische industrie'
#  'door het organiserende bedrijf, plus sponsoren' 'door voetbalvereniging'
#  'gratis door een vrijwilliger gegeven'
#  'het zijn gratis producttrainingen door de inkooporganisatie of een leverancier g'
#  'gommers heeft ons uitgenodigd deel te nemen'
#  'interne cursus zonder kosten' 'fnv' 'opdrachtgever'
#  'leverancier van de nieuwe producten' 'firma die de cursus geeft'
#  'geen idee' 'door het ikstartsmart project' 'is via de site van prorail'
#  'door vrijwilligerswerk organisatie' 'school'
#  'deels ikzelf, deels het gastouderbureau' 'politie' 'wwik'
#  'witsers moederbedrijf' 'lerarenbeurs' 'door een toeleverend bedrijf'
#  'ben zelf eigenaar' 'buurthuis/woningstichting'
#  'de franchisegever ( maar daar betalen we een fee aan, dus eigenlijk zelf)'
#  'leverancier' 'mijn man kan niet betaal voor mij' 'geen vergoeding'
#  'scouting' 'gratis' 'door de sponsor' 'via eigen bedrijf'
#  'is geen 2de cursus' 'geen kosten' 'opdrachtgever (goc)' 'aequor'
#  'rijksoverheid' 'gratis aanbod' 'niet, was een vriendendienst'
#  'st.bedrijfspensioenfonds'
#  'deze cursus wordt gegeven vanuit school. school betaald dus de kosten (cursisten'
#  'eigen bedrijf' 'ik ben. zelfstandig dus ikzelf'
#  'de organisatie waar we vrijwilligers werk doen'
#  'deze herhaling was gratis' 'ikzelf als werkgever'
#  'de vereniging betaald' 'vvv' 'astra satelliet' 'werkgever'
#  'voetbalvereniging' 'pleegzorgorganisatie' 'groothandel' 'maatschap'
#  'nvt gratis' 'o c en w' 'oude werkgever'
#  'waren geen kosten aan verbonden'
#  'organisatie tbv kinderopvang vermoed ik' '0' 'deels vakbond, deels zelf'
#  'heb ik zelf uitgerold met gemeentelijke middelen' 'ministerie'
#  'open training' 'organisatie stichting sensoor nederland' 'via humanitas'
#  'maatschapskosten' 'fabrikant' 'door de overkoepelende organsatie'
#  'op kosten van de fysiotherapiepraktijk waarvan ikzelf eigenaar ben'
#  'ik volg 1 cursus frans' 'cursus is gratis' 'eigen onderneming (bv)'
#  'ocw steunpunt cultuur' 'door bewonersonderneming  buurthuis'
#  'voormalig werkgever' 'het was een gratis cursus' 'maatschap kosten'
#  'er zijn geen kosten.' 'vrijwilligersorganisatie vwn'
#  'zie vorige vragen.' 'via zorgverzekering'
#  'mezelf en een deel door het uwv' 'deventer ziekenhuis'
#  'door leverancier'
#  'ikzelf betaalde. bij uitgave van eerste boek wordt het cursusgeld teruggestort (sept. 2016)'
#  'cnv intern' 'door branche' 'magento' 'geen kosten aan verbonden'
#  'het hoort bij het programma voor beginnende leerkrachten'
#  'de vereniging' 'een europeese beurs' 'mijn zzp bedrijf'
#  'organisatie vrijwilligerswerk' 'pensioenfonds horeca&catering'
#  'kosteloos' 'gratis cursus' 'was gratis proefcursus'
#  'bko cursussen zijn gratis voor medewerkers van de universiteit.' 'prive'
#  'wielrenvereniging' 'zaak' 'vrij cursus' nan]
#
# Column: 075
# ['' 'basketbalclub' 'rode kruis' 'instituut' 'restaurant' 'zwitserland'
#  'intern bij het bedrijf die de opleiding geeft'
#  'op lokatie ivm brandoefening' 'essence' 'de kromme rijn'
#  'commercieel trainingsburo' 'kindcentrum' 'bivag' 'burgerlijke gemeente'
#  'salto' 'leverancier van de software' 'opleidingsinstituut'
#  'geen opleiding meer' 'quadrant' 'siemens, zoetermeer' 'in een hotel'
#  'zwitserland/wengen' 'ncoi' 'seniorenweb' 'in het buitenland'
#  "bij collega's" 'nen' 'centric' 'buitenland' 'usa' 'vedaa'
#  'studiecentrum kerkebosch' 'hotel' 'civas' 'buurthuis' 'utrecht'
#  'gespecialiseerd instituut' 'particuliere instelling' 'pao farmacie'
#  'uwv' 'particulier' '0' 'zelfstudie' 'da vinci college'
#  'regionale brandweer midden en west brabant' 'toeleverancier'
#  'vergaderzaal' 'cahag' 'congreszaal' 'egmond aan zee'
#  'via werkgever, bij extern bureau' 'fabrikant' 'extern bureau' 'onderweg'
#  'intuitief traject' 'part.opleiding' 'engeland' 'via sba' 'n.v.t'
#  'postgrade' 'prive instituut' '.' 'locatie' 'osr' 'n.v.t.'
#  'via de friese poort' 'bhv.nl' 'nhi' 'bij beroepsviltsters' 'e-learning'
#  'breda' 'opleidinginstituut' 'nvt' 'opleidngsinstituut' 'geen'
#  'hotel in assen' 'venray' 'galerie de ganzerik' 'cure and care'
#  'trimbos / educare' 'lokatie' 'o' 'nvml (analisten vereniging)'
#  'belastingdienst' 'importeur' 'boston' 'netlaw' 'dordrecht' 'buitenpost'
#  'barqa' 'zermelo' 'ssr opleidingsinstituur ministerie van justitie'
#  'ggd jeugdzorg' 'hoofddorp' 'belgië' 'via slachtofferhulp' 'leusden'
#  'ligt in toekomst' 'politieacademie' 'cultuur en ondernemen' 'umcg'
#  'nergens' 'rijschool' 'binnen eigen instelling' 'fudge kantoor' 'niet'
#  'schoolbegeleidingsdienst' 'internet' 'leverancier' 'duur' 'vidacto'
#  'schoevers, na werktijd' 'zalen centrum' 'pro education' 'xx'
#  'particuliere aanbieder' 'via nederlandse vereniging van rentmeesters'
#  'kpn consulting' 'congres' 'centrale plaats groningen' 'swa' 'polteq'
#  'produktleverancier' 'venvn' 'groep' 'itan' 'onafhankelijk bedrijf'
#  'aequor' 'op twerk' 'olpen' 'ziekenhuis' 'vrijwilligersorganisatie' 'g4s'
#  'systeembeheer' 'conferentie zaal'
#  'particulier instituut: hotel in valkenburg' 'online' 'cpo'
#  'bij kunstenaar in atelier' 'vergouwen overduin'
#  'europees veterinair congres'
#  'bijeenkomsten worden gehouden in een vergader/congress ruimte van een hotel'
#  'opleidingscentrum' 'zelf uitzoeken' 'van der valk hotel'
#  'symposium zorgbelang zh' 'werkgever' 'deloitte' 'fysikos' 'falck' 'a'
#  'alro deurne' 'diversen' 'colorado springs, vs' 'rovc'
#  'vrijwilligersorganisatie sensoor' 'training centrum'
#  'aeon loopbaanadvies' 'internationaal congres' 'geen cursus' 'veldhoven'
#  'bij een andere organisatie' 'thuis' 'lexima' 'ocw steunpunt cultuur'
#  'bij de salarisverwerker adp' 'saasen groep' 'zelf' 'lindenhaeghe'
#  'in hotel gehuurd door farmaceutsiche industrie' 'scem' 'koh'
#  'online cursus' 'adviesbureau' 'via werkgever ingehuurde trainer' 'kpc'
#  'eindhoven' 'cnls' 'niet gevolgd' 'edx (mooc)' 'commercieel buro' 'rino'
#  'speel je wijs' 'tstc veenendaal' 'culemborg' 'cnv intern' 'wft nivo'
#  'sfol' 'sportschool' 'synergio' 'son' 'organisatie' 'bedrijf produkten'
#  '*****' 'thuis e learning' '-' 'particuliere opleider' 'boz'
#  'leraren huis' 'cinemec ede' 'alkmaar' 'computer /school'
#  'jaarbeurs te utrecht' 'prive' '?' 'new york' 'berg bhv' 'op locatie'
#  'nederlandse orde voor belastingadviseurs' 'particulier instituut' nan]

# %%
df_clean2= clean_full_dataset(df_clean).copy()

# %% [markdown]
# ## 6. Filter respondents

# %%
# Filter to only working individuals 
filtered_df = filter_by_conditions(df_clean2)
print("Original shape:", df_clean2.shape)
print("Filtered shape:", filtered_df.shape)
# Out:
# Original shape: (99411, 411)
# Filtered shape: (56766, 411)

# %% [markdown]
# ## 7. Filter regimes

# %%
# SPlit into the 3 regimes
regimes = split_by_regime(filtered_df)

# %% [markdown]
# ## 8. Delete empty target values

# %%
regimes = drop_missing_target_for_regimes(regimes, target="127")
# Out:
# Rows removed due to missing target '127': 388
# Remaining rows after filtering: 21367
# Rows removed due to missing target '127': 600
# Remaining rows after filtering: 19082
# Rows removed due to missing target '127': 274
# Remaining rows after filtering: 15055

# %%
# Inspect the regimes
summarize_regimes(regimes)

# to access each regime
df_regime_a = regimes["A"]
df_regime_b = regimes["B"]
df_regime_c = regimes["C"]
# Out:
# Regime A: years=[2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0], shape=(21367, 411)
# Regime B: years=[2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0], shape=(19082, 411)
# Regime C: years=[2020.0, 2021.0, 2022.0, 2023.0, 2024.0], shape=(15055, 411)

# %% [markdown]
# ## 9. Save Results

# %%
def save_parquet(df, *path_parts):
    full_path = os.path.join(project_root, "data", *path_parts)
    os.makedirs(os.path.dirname(full_path), exist_ok=True)
    df.to_parquet(full_path)

save_parquet(df_clean, "clean", "df_clean.parquet")
save_parquet(df_regime_a, "regimes", "regime_a.parquet")
save_parquet(df_regime_b, "regimes", "regime_b.parquet")
save_parquet(df_regime_c, "regimes", "regime_c.parquet")

# %%
print("df_clean shape:", df_clean.shape)
print("regime A shape:", df_regime_a.shape)
print("regime B shape:", df_regime_b.shape)
print("regime C shape:", df_regime_c.shape)

print(df_regime_a.head())
print(df_regime_b.head())
print(df_regime_c.head())
# Out:
# df_clean shape: (99411, 411)
# regime A shape: (21367, 411)
# regime B shape: (19082, 411)
# regime C shape: (15055, 411)
#    001   003  004   005  006   008  009  011  012  013  ...  604  605  606  \
# 0  1.0  16.0  8.0   3.0  NaN  12.0  NaN  1.0  0.0  0.0  ...  NaN  NaN  NaN
# 1  1.0  32.0  5.0  13.0  NaN  18.0  NaN  0.0  0.0  0.0  ...  NaN  NaN  NaN
# 2  1.0  33.0  9.0  23.0  NaN  22.0  NaN  0.0  0.0  0.0  ...  NaN  NaN  NaN
# 5  1.0  52.0  7.0   6.0  NaN   5.0  NaN  0.0  0.0  0.0  ...  NaN  NaN  NaN
# 6  1.0  38.0  7.0  16.0  NaN  15.0  NaN  0.0  0.0  0.0  ...  NaN  NaN  NaN
#
#    607  608  609  610  611  612  613
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 5  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 6  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 411 columns]
#        001   003  004   005  006   008  009  011  012  013  ...  604  605  \
# 35975  1.0  44.0  7.0   8.0  NaN   7.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
# 35976  1.0  51.0  8.0  25.0  NaN  24.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
# 35977  1.0  34.0  8.0  18.0  NaN  17.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
# 35978  1.0  38.0  6.0  13.0  NaN  18.0  NaN  0.0  1.0  0.0  ...  NaN  NaN
# 35979  1.0  67.0  7.0   8.0  NaN   7.0  NaN  1.0  0.0  0.0  ...  NaN  NaN
#
#        606  607  608  609  610  611  612  613
# 35975  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35976  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35977  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35978  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 35979  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 411 columns]
#        001   003  004   005  006   008  009  011  012  013  ...  604  605  \
# 71582  1.0  57.0  NaN  26.0  NaN  25.0  NaN  0.0  0.0  0.0  ...  4.0  NaN
# 71583  1.0  45.0  NaN  24.0  NaN  23.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
# 71584  1.0  22.0  NaN  13.0  NaN  19.0  NaN  1.0  0.0  0.0  ...  NaN  NaN
# 71585  1.0  29.0  NaN  17.0  NaN  16.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
# 71587  1.0  23.0  NaN  17.0  NaN  16.0  NaN  0.0  0.0  0.0  ...  NaN  NaN
#
#        606  607  608  609  610     611  612  613
# 71582  NaN  NaN  NaN  NaN  0.0  2632.0  NaN  NaN
# 71583  NaN  NaN  NaN  NaN  4.0  2120.0  NaN  NaN
# 71584  NaN  NaN  NaN  NaN  0.0  5131.0  NaN  NaN
# 71585  NaN  NaN  NaN  NaN  0.0  5322.0  NaN  NaN
# 71587  NaN  NaN  NaN  NaN  0.0  9122.0  NaN  NaN
#
# [5 rows x 411 columns]
