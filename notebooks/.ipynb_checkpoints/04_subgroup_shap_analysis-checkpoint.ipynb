# %% [markdown]
# # 03 — Subgroup SHAP Analysis

# %% [markdown]
# ## 1. Overview

# %% [markdown]
# This notebook performs subgroup SHAP analyses both within and across regimes. For each regime, SHAP values are computed separately for each model and each subgroup. These SHAP outputs are then converted into feature‑rank matrices to evaluate how stable feature importance is:
#
# * Within each regime:
# We compare models inside the same regime to assess how consistently they rank features for a given subgroup.
#
# * Across regimes:
# We compare subgroup‑level feature rankings across different regimes to identify shared patterns and regime‑specific differences.

# %%
import sys
import os

# Get the project root (one level above the notebook folder)
project_root = os.path.abspath("..")

# Add it to Python path
if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added:", project_root)
# Out:
# Project root added: C:\Users\shari\OneDrive\MSc Data Science and Society\Thesis_DSS_2026

# %% [markdown]
# ## 2. Imports

# %%
import numpy as np
import pandas as pd

import pickle
import joblib

import sys
import os

# Now import the functions
from src.shap_subgroup import (
    build_subgroups,   
    attach_all_subgroups,
    subgroup_rank_variance,
    plot_all_subgroup_profiles,
    compute_subgroup_shap_analysis,
    rename_features
)

from src.shap_analysis import (
    compute_shap_xgb_per_regime,
    compute_across_regime_shap_common_features,
    summarize_volatile_stable_features,
    safe_save_plot
)

# ============================================
# Optional: Warnings Control
# ============================================
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 3. Load Datasets

# %%
# ---------------------------------------------------------
# Project paths
# ---------------------------------------------------------
project_root = os.path.abspath("..")
sys.path.append(project_root) if project_root not in sys.path else None

data_dir = os.path.join(project_root, "data")
output_dir = "shap_results_saved"

print("Project root:", project_root)
print("Data directory:", data_dir)

# ---------------------------------------------------------
# Load saved SHAP results
# ---------------------------------------------------------
with open(os.path.join(output_dir, "across_regime_results.pkl"), "rb") as f:
    across_regime_results_loaded = pickle.load(f)

with open(os.path.join(output_dir, "within_regime_results.pkl"), "rb") as f:
    shap_results_per_regime = pickle.load(f)

# ---------------------------------------------------------
# Load model evaluation results
# ---------------------------------------------------------
ALL_RESULTS = joblib.load("results/all_results.joblib")

# ---------------------------------------------------------
# Load raw data for regimes
# ---------------------------------------------------------
df_clean = pd.read_parquet(os.path.join(data_dir, "clean", "df_clean.parquet"))

df_regime_a = pd.read_parquet(os.path.join(data_dir, "regimes", "regime_a.parquet"))
df_regime_b = pd.read_parquet(os.path.join(data_dir, "regimes", "regime_b.parquet"))
df_regime_c = pd.read_parquet(os.path.join(data_dir, "regimes", "regime_c.parquet"))
# Out:
# Project root: C:\Users\shari\OneDrive\MSc Data Science and Society\Thesis_DSS_2026
# Data directory: C:\Users\shari\OneDrive\MSc Data Science and Society\Thesis_DSS_2026\data

# %% [markdown]
# ## 4. Subgroup Analysis

# %%
# Extract common features across regimes
common_features = across_regime_results_loaded["common_features_raw"]

print("Number of common features:", len(common_features))
print("Example:", common_features[:10])


all_subgroup_results = {}

raw_dfs = {
    "Regime A": df_regime_a,
    "Regime B": df_regime_b,
    "Regime C": df_regime_c
}

for regime_name in shap_results_per_regime.keys():
    print(f"\n=== Running subgroup SHAP analysis for {regime_name} ===")

    shap_res = shap_results_per_regime[regime_name]
    shap_values = shap_res["shap_values"]
    feature_names = shap_res["X_full"].columns

    model_name = "XGBoost"
    X_test = ALL_RESULTS[regime_name]["results"][model_name]["X_test"]

    df_regime_raw = raw_dfs[regime_name]

    subgroup_results = compute_subgroup_shap_analysis(
        shap_values=shap_values,
        X_test=X_test,
        df_regime_raw=df_regime_raw,
        feature_names=feature_names,
        build_subgroups_fn=build_subgroups,
        top_n=20
    )


    # Restrict subgroup profiles to common features
    subgroup_profiles_common = {
        subgroup: profile.loc[common_features]
        for subgroup, profile in subgroup_results["subgroup_profiles"].items()
        if set(common_features).issubset(profile.index)
    }

    # Compute rank variance for common features
    subgroup_rank_variance_common = {}
    for subgroup, profile in subgroup_profiles_common.items():
        rank_df = profile.rank(ascending=False, axis=0)
        rank_var = rank_df.var(axis=1).sort_values(ascending=False)
        subgroup_rank_variance_common[subgroup] = rank_var

    # Store everything
    all_subgroup_results[regime_name] = {
        "shap_df": subgroup_results["shap_df"],
        "subgroup_cols": subgroup_results["subgroup_cols"],
        "subgroup_profiles_full": subgroup_results["subgroup_profiles"],
        "subgroup_profiles_common": subgroup_profiles_common,
        "rank_variance_full": subgroup_results["subgroup_rank_variance"],
        "rank_variance_common": subgroup_rank_variance_common
    }

print("\n=== Subgroup SHAP analysis completed for all regimes ===")
# Out:
# Number of common features: 63
# Example: ['binary__088', 'binary__095', 'binary__096', 'binary__101', 'binary__102', 'binary__390', 'binary__391', 'binary__392', 'binary__393', 'binary__394']
#
# === Running subgroup SHAP analysis for Regime A ===
# === Running subgroup SHAP analysis for Regime B ===
# === Running subgroup SHAP analysis for Regime C ===
# === Subgroup SHAP analysis completed for all regimes ===

# %%
feature_name_map = {
    # -------------------------
    # Your original mappings
    # -------------------------
    "num__143": "Has sideline job",
    "num__409": "Supervises employees",
    "num__446": "Works less to care for children",
    "binary__391": "Reason <36h: family situation",
    "binary__390": "Reason <36h: no opportunity to work more",
    "binary__393": "Reason <36h: home activities",
    "binary__401": "Reason <36h: other",
    "binary__400": "Reason <36h: more leisure",
    "binary__088": "Currently employed",
    "num__404": "Occupation (current job)",
    "num__402": "Sector",
    "num__122": "Retirement feeling",
    "num__289": "Expected retirement age",
    "num__008": "Education completed (2nd degree)",
    "num__479": "Savings deposit (2007)",
    "num__384": "Max full-time wage estimate",
    "num__136": "Commute to work (minutes)",
    "num__032": "Education–work match scale",
    "num__003": "Age",
    "num__022": "Preferred retirement age",
    "num__459": "Lifecourse deposit (2007)",
    "num__438": "No children or grandchildren",
    "num__450": "Provides informal care",
    "num__123": "Organisation type (first job)",
    "num__035": "Has taken job courses",
    "binary__437": "Has grandchildren",
    "binary__492": "Reason <36h: family/health",
    "num__missingindicator_141": "Missing: weekend work frequency",
    "num__missingindicator_142": "Missing: evening work frequency",
    "num__missingindicator_517": "Missing: minimum wage offer",
    "num__missingindicator_405": "Missing: occupation (first job)",
    "num__missingindicator": "Missing: irregular work hours",
    "num__411": "Option to continue working after pension",
    "num__missingindicator_411": "Missing: option to continue after pension",
    "num__missingindicator_134": "Missing: year started working",
    "num__517": "Minimum wage offer (EUR)",
    "num__missingindicator_035": "Missing: took job courses",
    "num__missingindicator_528": "Missing: workplace size",
    "num__611": "Profession (ISCO 085)",
    "num__missingindicator_309": "Missing: desired part-time hours",
    "num__missingindicator_136": "Missing: commute to work (minutes)",
    "num__005": "Highest Dutch education",
    "num__308": "Retirement transition preference",
    "num__610": "Weekly home-work hours",
    "num__309": "Desired part-time hours",
    "num__134": "Year started working",
    "num__528": "Workplace size",
    "num__141": "Weekend work frequency",
    "binary__395": "Reason <36h: health",

    # -------------------------
    # Your NEW improved mappings
    # -------------------------
    "binary__438": "No children or grandchildren",
    "binary__396": "Reason <36h: disability",
    "num__439": "Has children under age 8",
    "binary__436": "Has children",
    "binary__393": "Reason <36h: home activities",   # updated from your note
    "num__288": "Stopped working age",
    "num__140": "Evening work frequency",
    "binary__101": "Does voluntary work",
    "binary__096": "Does household work",
    "num__405": "Occupation (first job)",
    "num__missingindicator_122": "Missing: organisation type (current job)",
    "num__missingindicator_140": "Missing: evening work frequency",
    "binary__394": "Reason <36h: other activities",
    "binary__397": "Reason <36h: partial retirement",
    "binary__392": "Reason <36h: family/health",
    "num__missingindicator_409": "Missing: supervises employees",
    "num__missingindicator_450": "Missing: provides informal care",
    "num__missingindicator_122": "Missing: organisation type (current job)"
}

feature_name_map.update({
    "binary__095": "Is student with expense claim",
    "binary__399": "Reason <36h: take it easier"
})

# %%
TOP_N = 15

for regime_name, results in all_subgroup_results.items():
    print("\n" + "="*80)
    print(f"SUBGROUP PROFILES (TOP {TOP_N} COMMON FEATURES) — {regime_name}")
    print("="*80)

    for subgroup, profile in results["subgroup_profiles_common"].items():
        # Select top 15 features by mean SHAP across subgroups
        top_features = (
            profile.mean(axis=1)
            .sort_values(ascending=False)
            .head(TOP_N)
            .index
        )

        print(f"\n--- {subgroup} ---")
        print(profile.loc[top_features])
# Out:
# ================================================================================
# SUBGROUP PROFILES (TOP 15 COMMON FEATURES) — Regime A
# ================================================================================
#
# --- age_group ---
# age_group       Young  Mid-career     Older
# binary__391  0.516676   -0.564752  0.497493
# num__446     0.150671   -0.169026  0.201789
# binary__438  0.201821   -0.019569 -0.051261
# num__122     0.075291    0.024439  0.000813
# binary__396  0.103446    0.029012 -0.059795
# binary__096  0.038004   -0.020764  0.051969
# num__439     0.018377   -0.041049  0.078891
# binary__436  0.056653   -0.004620 -0.005535
# binary__392  0.028220    0.015769  0.000402
# num__140    -0.029221    0.033584  0.035021
# num__402    -0.058572    0.115318 -0.019662
# binary__101  0.033203   -0.002239  0.002574
# num__288     0.019520    0.003798  0.006304
# num__289     0.123824    0.056010 -0.150292
# num__141     0.074568   -0.042103 -0.011668
#
# --- sector_group ---
# sector_group               Agriculture & Extraction  Culture & Other Services  \
# num__402                                   1.537706                 -0.252765
# num__409                                   0.877860                 -0.073125
# binary__391                                0.885324                  0.130664
# binary__401                                0.719667                 -0.322985
# num__141                                   0.894016                  0.038601
# num__122                                   0.308337                  0.155620
# num__405                                   0.631634                 -0.006184
# num__missingindicator_122                  0.615173                  0.018449
# num__140                                   0.459698                  0.007426
# num__446                                   0.227848                  0.026962
# num__missingindicator_140                  0.129928                 -0.003527
# num__missingindicator_405                  0.041964                  0.012482
# binary__390                                0.120516                 -0.138357
# binary__395                                0.277661                 -0.000740
# binary__394                                0.169455                 -0.027663
#
# sector_group               Production & Construction  \
# num__402                                    1.292933
# num__409                                    0.450451
# binary__391                                 0.592843
# binary__401                                 0.430664
# num__141                                   -0.202349
# num__122                                    0.276847
# num__405                                    0.123201
# num__missingindicator_122                  -0.030638
# num__140                                    0.006142
# num__446                                    0.162070
# num__missingindicator_140                   0.063242
# num__missingindicator_405                   0.080708
# binary__390                                 0.373780
# binary__395                                 0.051522
# binary__394                                 0.141435
#
# sector_group               Public & Social Services  Trade & Market Services
# num__402                                  -0.650916                 0.489770
# num__409                                  -0.126122                 0.046389
# binary__391                               -0.531876                 0.062416
# binary__401                               -0.003968                -0.034812
# num__141                                  -0.053059                 0.085304
# num__122                                  -0.279607                 0.224416
# num__405                                  -0.053618                -0.047639
# num__missingindicator_122                 -0.045429                 0.001185
# num__140                                   0.009908                 0.026999
# num__446                                  -0.050075                -0.056583
# num__missingindicator_140                  0.032634                -0.001392
# num__missingindicator_405                  0.057729                 0.015524
# binary__390                               -0.202689                 0.046125
# binary__395                               -0.205880                 0.071303
# binary__394                               -0.024006                -0.067943
#
# --- life_situation ---
# life_situation      None  Provides care
# binary__391     0.973622      -0.590496
# num__446        0.294131      -0.155225
# binary__438     0.229307      -0.108697
# num__402        0.044039       0.048375
# binary__393     0.223810      -0.153716
# num__122        0.050585       0.015002
# num__439        0.069590      -0.026885
# num__140       -0.008571       0.042885
# binary__436     0.052167      -0.019289
# binary__392     0.028182       0.003402
# binary__397     0.061276      -0.030630
# binary__096     0.035101      -0.005510
# num__289        0.063961      -0.034959
# num__003        0.064601      -0.039754
# num__450        0.045534      -0.021988
#
# --- education_group ---
# education_group            Agriculture  Arts_Humanities  Business_Law  \
# num__409                      0.718973        -0.027043      0.222410
# num__140                      0.344369         0.031548     -0.064585
# num__402                      0.647846        -0.279235      0.156500
# num__141                      0.422635         0.111916     -0.132638
# binary__401                   0.628004        -0.644662      0.149290
# num__405                      0.511154        -0.071136     -0.107424
# binary__391                   0.630326         0.024635     -0.333025
# num__122                      0.155581        -0.081425      0.056108
# num__missingindicator_405     0.026741         0.002645      0.038080
# num__missingindicator_122     0.260722         0.005756     -0.004283
# binary__393                   0.349817         0.044430      0.100210
# num__missingindicator_140     0.051214         0.054291      0.099397
# num__446                      0.217061        -0.033430     -0.135172
# binary__096                   0.097439        -0.028619      0.009930
# binary__394                   0.164667        -0.037184     -0.009023
#
# education_group            Education  Health_Care      STEM  Services
# num__409                   -0.351703    -0.227093  0.171563  0.285858
# num__140                   -0.067972    -0.000059  0.070934  0.385097
# num__402                    0.090055    -0.720304  0.457988  0.333742
# num__141                   -0.037473     0.031898 -0.035594  0.300357
# binary__401                -0.063109    -0.076650  0.138925  0.246722
# num__405                   -0.076214    -0.075730  0.133802  0.045147
# binary__391                -0.120612    -0.936718  0.801561  0.203280
# num__122                    0.012110    -0.104294  0.127207  0.068134
# num__missingindicator_405  -0.021709     0.038301  0.038745  0.070260
# num__missingindicator_122  -0.004864    -0.026287 -0.026578 -0.030013
# binary__393                -0.196426    -0.496462  0.284534  0.066113
# num__missingindicator_140  -0.012417    -0.058270  0.032898 -0.018030
# num__446                    0.020362    -0.092156  0.176408 -0.004770
# binary__096                -0.052930    -0.068300  0.098439  0.091556
# binary__394                -0.102005    -0.030403  0.059435  0.097629
#
# ================================================================================
# SUBGROUP PROFILES (TOP 15 COMMON FEATURES) — Regime B
# ================================================================================
#
# --- age_group ---
# age_group                     Young  Mid-career     Older
# binary__391                0.350199   -0.401814  0.298434
# num__402                   0.038226    0.132388 -0.051416
# num__528                   0.019590    0.074328  0.023804
# num__missingindicator_405 -0.039673    0.056125  0.062933
# binary__396                0.076264    0.045704 -0.045304
# num__446                   0.117172   -0.143028  0.099182
# num__missingindicator_528  0.051565   -0.006212  0.015901
# binary__438                0.152731   -0.031828 -0.065173
# binary__395                0.145990    0.021149 -0.122782
# num__missingindicator_409 -0.054924    0.048718  0.048850
# num__missingindicator_450  0.027884    0.003306  0.009976
# num__008                   0.053792    0.033492 -0.059919
# num__136                  -0.017521    0.071427 -0.027910
# binary__397                0.042462    0.041610 -0.059495
# num__134                   0.027242   -0.017444  0.014288
#
# --- sector_group ---
# sector_group               Agriculture & Extraction  Culture & Other Services  \
# num__402                                   1.874739                 -0.578929
# binary__391                                0.480681                  0.124039
# binary__390                                0.483369                 -0.067137
# num__409                                   0.378751                 -0.014879
# num__143                                   0.153554                  0.012027
# binary__393                                0.351794                 -0.107577
# binary__400                                0.233432                  0.018833
# binary__394                                0.102852                  0.052289
# num__140                                   0.241500                 -0.008105
# num__122                                   0.068086                  0.038816
# num__141                                   0.224153                  0.105847
# num__missingindicator_122                  0.330743                 -0.028658
# binary__396                                0.077024                  0.038153
# num__missingindicator_405                 -0.028016                  0.036338
# num__446                                   0.096734                  0.014259
#
# sector_group               Production & Construction  \
# num__402                                    1.261254
# binary__391                                 0.521537
# binary__390                                 0.623750
# num__409                                    0.137042
# num__143                                    0.173463
# binary__393                                 0.311024
# binary__400                                 0.278301
# binary__394                                 0.056390
# num__140                                   -0.012879
# num__122                                    0.151027
# num__141                                   -0.132714
# num__missingindicator_122                  -0.052919
# binary__396                                 0.000891
# num__missingindicator_405                   0.062801
# num__446                                    0.068917
#
# sector_group               Public & Social Services  Trade & Market Services
# num__402                                  -0.698144                 0.802793
# binary__391                               -0.362401                 0.156694
# binary__390                               -0.269348                 0.019974
# num__409                                  -0.131434                 0.065509
# num__143                                  -0.043537                 0.036333
# binary__393                               -0.243203                -0.012658
# binary__400                               -0.261114                -0.044926
# binary__394                               -0.014412                 0.015196
# num__140                                  -0.016454                 0.000755
# num__122                                  -0.171885                 0.107674
# num__141                                  -0.088076                 0.071191
# num__missingindicator_122                 -0.038991                -0.038943
# binary__396                               -0.010701                 0.054040
# num__missingindicator_405                  0.057056                 0.017827
# num__446                                  -0.054970                 0.019000
#
# --- life_situation ---
# life_situation                 None  Provides care
# binary__391                0.756424      -0.474137
# num__402                   0.107293       0.007732
# num__528                   0.047492       0.042688
# num__446                   0.199237      -0.130274
# num__missingindicator_405 -0.002443       0.063886
# binary__438                0.163751      -0.112107
# binary__396                0.036806       0.009168
# num__missingindicator_409 -0.016140       0.053855
# num__136                   0.026957       0.010501
# num__143                   0.007073       0.026358
# num__missingindicator_140 -0.054158       0.079512
# binary__394               -0.011978       0.036966
# num__008                   0.041812      -0.019233
# num__003                   0.145447      -0.124832
# binary__395                0.068924      -0.049402
#
# --- education_group ---
# education_group            Agriculture  Arts_Humanities  Business_Law  \
# num__402                      0.637352        -0.248663      0.292209
# num__missingindicator_405     0.069721         0.038528      0.042187
# num__141                      0.140978         0.056868     -0.087943
# num__528                      0.029966         0.044550      0.107277
# num__missingindicator_141     0.081718         0.018735      0.060017
# binary__396                   0.078077         0.077892      0.044339
# num__missingindicator_409     0.056575         0.022384      0.033516
# num__missingindicator_134     0.126354         0.008299      0.053490
# num__missingindicator_140     0.127642         0.070632      0.117610
# num__136                      0.112744         0.119050      0.035393
# num__missingindicator_136     0.065018         0.019388      0.034321
# binary__394                   0.047273        -0.080334      0.051640
# num__missingindicator_142     0.044188         0.011122      0.027618
# num__409                      0.316202         0.067870      0.138231
# binary__401                   0.320571        -0.160002      0.161949
#
# education_group            Education  Health_Care      STEM  Services
# num__402                    0.157714    -1.039961  0.427403  0.529868
# num__missingindicator_405  -0.000064     0.046878  0.044917  0.060098
# num__141                   -0.080250     0.048180 -0.009512  0.199968
# num__528                    0.006238    -0.064404  0.080852  0.063106
# num__missingindicator_141  -0.085179     0.051187  0.047699  0.090963
# binary__396                -0.039365     0.015146  0.009000  0.033825
# num__missingindicator_409  -0.012113     0.032999  0.035400  0.046346
# num__missingindicator_134  -0.175563     0.050254  0.040894  0.109761
# num__missingindicator_140  -0.048215    -0.039282  0.030386 -0.058907
# num__136                   -0.097630    -0.095652  0.091940  0.028140
# num__missingindicator_136  -0.047093     0.031845  0.031759  0.057514
# binary__394                -0.008615     0.016625  0.027464  0.098771
# num__missingindicator_142  -0.039982     0.025983  0.022419  0.042516
# num__409                   -0.244067    -0.285811  0.072546  0.068613
# binary__401                -0.352743    -0.047848  0.063044  0.143916
#
# ================================================================================
# SUBGROUP PROFILES (TOP 15 COMMON FEATURES) — Regime C
# ================================================================================
#
# --- age_group ---
# age_group                     Young  Mid-career     Older
# num__136                   0.104260    0.083839  0.002228
# binary__397                0.069736    0.064194 -0.018076
# num__005                   0.036230    0.091763 -0.015242
# num__missingindicator_142  0.106476    0.000278  0.003593
# num__402                  -0.005941    0.026932  0.082664
# binary__393                0.076725    0.036931 -0.015303
# num__528                   0.027787    0.030062  0.023129
# num__134                   0.003331    0.014695  0.048086
# num__missingindicator_288  0.004522    0.014518  0.043253
# num__142                   0.034327    0.009077  0.007014
# num__035                   0.048316    0.023738 -0.024804
# num__missingindicator_141  0.016678    0.011085  0.012717
# binary__437                0.053468    0.047097 -0.064073
# num__289                   0.032196    0.028212 -0.027428
# num__409                  -0.077289    0.050868  0.058780
#
# --- sector_group ---
# sector_group               Agriculture & Extraction  Culture & Other Services  \
# num__402                                   1.169996                 -0.283702
# num__409                                   0.474060                  0.125395
# num__missingindicator_405                  0.237516                  0.049235
# binary__400                                0.552503                  0.038830
# binary__393                                0.317137                  0.022848
# binary__391                                0.356239                 -0.031616
# num__missingindicator_409                  0.081734                  0.029155
# binary__397                                0.075500                  0.032784
# num__134                                   0.126334                  0.037210
# num__141                                   0.291489                  0.020857
# num__136                                  -0.032989                 -0.029723
# binary__401                                0.141036                 -0.178715
# num__528                                   0.095912                 -0.034906
# num__122                                   0.021100                  0.061432
# num__405                                   0.093164                  0.007084
#
# sector_group               Production & Construction  \
# num__402                                    1.244405
# num__409                                    0.181731
# num__missingindicator_405                   0.228011
# binary__400                                 0.221257
# binary__393                                 0.188313
# binary__391                                 0.448456
# num__missingindicator_409                   0.074149
# binary__397                                 0.080047
# num__134                                   -0.001900
# num__141                                   -0.126755
# num__136                                    0.149133
# binary__401                                 0.311845
# num__528                                    0.024366
# num__122                                    0.104467
# num__405                                    0.050317
#
# sector_group               Public & Social Services  Trade & Market Services
# num__402                                  -0.504784                 0.406530
# num__409                                  -0.101344                 0.185900
# num__missingindicator_405                  0.249145                 0.060097
# binary__400                               -0.360358                 0.041240
# binary__393                               -0.124422                 0.088265
# binary__391                               -0.492971                 0.030069
# num__missingindicator_409                  0.078658                 0.028309
# binary__397                                0.020826                 0.012677
# num__134                                   0.010521                 0.045251
# num__141                                  -0.090534                 0.089000
# num__136                                   0.104738                -0.017930
# binary__401                               -0.113777                 0.011088
# num__528                                   0.034278                 0.033459
# num__122                                  -0.121517                 0.086719
# num__405                                  -0.027700                 0.009351
#
# --- life_situation ---
# life_situation                 None  Provides care
# num__136                   0.069141       0.045652
# binary__393                0.175440      -0.074979
# num__402                   0.046907       0.040659
# num__005                   0.048392       0.031348
# binary__397                0.066451       0.009939
# binary__391                0.586128      -0.523539
# num__446                   0.232123      -0.170161
# num__missingindicator_142  0.056938      -0.000368
# num__134                   0.028383       0.024954
# num__528                   0.025456       0.027499
# num__missingindicator_288  0.014876       0.030159
# binary__394                0.008909       0.019819
# num__142                   0.017875       0.010058
# num__missingindicator_141  0.015260       0.011294
# num__288                   0.009644       0.016510
#
# --- education_group ---
# education_group            Agriculture  Arts_Humanities  Business_Law  \
# num__136                      0.001919         0.159444      0.054805
# num__missingindicator_405    -0.123144         0.008275      0.143498
# num__409                      0.100873        -0.087670      0.151851
# binary__397                   0.066770         0.074890     -0.008009
# num__528                     -0.006467         0.053705      0.046459
# num__142                      0.069860        -0.023399     -0.042614
# num__402                      0.203057        -0.149575      0.126174
# num__134                      0.059991        -0.005116      0.039872
# num__missingindicator_142     0.072421         0.025839      0.015950
# num__missingindicator_288     0.035663         0.019133      0.020815
# num__missingindicator_409    -0.004821         0.011668      0.056018
# num__005                     -0.129113         0.230735      0.097159
# num__140                      0.111328        -0.016407     -0.013571
# binary__393                   0.143075        -0.050598      0.115303
# num__288                     -0.016485         0.009338      0.004804
#
# education_group            Education  Health_Care      STEM  Services
# num__136                   -0.039289     0.027472  0.070101  0.110119
# num__missingindicator_405  -0.089945     0.135924  0.075338  0.191539
# num__409                   -0.171158    -0.160864  0.101534  0.402082
# binary__397                 0.048588     0.005384  0.041352  0.071085
# num__528                    0.014985     0.012029  0.007003  0.072692
# num__142                    0.058694     0.069694  0.005308  0.057944
# num__402                   -0.030721    -0.515438  0.335727  0.224752
# num__134                    0.015738     0.030389  0.028299  0.021984
# num__missingindicator_142   0.047367     0.005915  0.018776  0.003057
# num__missingindicator_288   0.028394     0.021793  0.026223  0.028517
# num__missingindicator_409  -0.010212     0.034025  0.030985  0.056177
# num__005                   -0.129549     0.035787  0.027474 -0.016688
# num__140                   -0.064340     0.040779  0.021999  0.034755
# binary__393                -0.141528    -0.190590  0.147951  0.082246
# num__288                    0.018408     0.037598  0.006071  0.039727

# %%
for regime_name, results in all_subgroup_results.items():
    print("\n" + "="*80)
    print(f"RANK VARIANCE (TOP {TOP_N} COMMON FEATURES) — {regime_name}")
    print("="*80)

    for subgroup, rank_var in results["rank_variance_common"].items():
        top_features = rank_var.head(TOP_N)

        print(f"\n--- {subgroup} ---")
        print(top_features)
# Out:
# ================================================================================
# RANK VARIANCE (TOP 15 COMMON FEATURES) — Regime A
# ================================================================================
#
# --- age_group ---
# binary__391                  1281.333333
# num__446                     1161.333333
# num__missingindicator_035    1143.000000
# binary__095                  1102.333333
# num__409                     1029.000000
# num__003                     1026.333333
# binary__393                  1017.333333
# binary__401                   984.333333
# num__404                      940.333333
# binary__399                   937.333333
# binary__400                   903.000000
# binary__438                   871.000000
# binary__395                   867.000000
# binary__390                   829.000000
# num__289                      758.333333
# dtype: float64
#
# --- sector_group ---
# num__402                     1116.8
# num__141                      920.5
# num__404                      915.2
# num__missingindicator_035     763.5
# num__409                      757.3
# binary__390                   713.3
# binary__401                   709.5
# binary__391                   697.7
# binary__400                   687.8
# num__136                      652.3
# num__122                      644.0
# num__446                      639.5
# binary__095                   623.8
# num__008                      597.3
# num__missingindicator_411     585.7
# dtype: float64
#
# --- life_situation ---
# binary__391                  1922.0
# num__missingindicator_035    1860.5
# num__446                     1800.0
# binary__401                  1800.0
# binary__095                  1682.0
# num__409                     1624.5
# binary__393                  1624.5
# binary__438                  1568.0
# num__404                     1458.0
# num__008                     1352.0
# num__missingindicator_411    1300.5
# num__missingindicator_140    1300.5
# binary__399                  1250.0
# num__missingindicator_405    1104.5
# num__003                     1058.0
# dtype: float64
#
# --- education_group ---
# num__404                     882.285714
# binary__390                  861.238095
# num__402                     838.142857
# binary__391                  837.904762
# num__409                     819.904762
# num__141                     754.000000
# binary__397                  699.285714
# binary__401                  680.000000
# num__008                     677.238095
# num__446                     663.809524
# binary__393                  604.142857
# num__136                     599.238095
# binary__400                  586.952381
# num__003                     582.952381
# num__missingindicator_035    560.476190
# dtype: float64
#
# ================================================================================
# RANK VARIANCE (TOP 15 COMMON FEATURES) — Regime B
# ================================================================================
#
# --- age_group ---
# num__missingindicator_035    1281.333333
# binary__391                  1261.000000
# num__003                     1240.333333
# num__missingindicator_134    1141.000000
# binary__393                  1121.333333
# num__446                     1066.333333
# binary__401                  1012.333333
# binary__438                   960.333333
# num__404                      956.333333
# num__missingindicator_141     937.333333
# binary__400                   917.333333
# binary__390                   850.333333
# binary__399                   817.000000
# num__missingindicator_140     764.333333
# num__missingindicator_136     691.000000
# dtype: float64
#
# --- sector_group ---
# num__402                     1153.2
# num__missingindicator_035    1068.7
# num__141                      867.5
# binary__390                   860.7
# num__404                      856.8
# binary__401                   829.3
# binary__400                   813.2
# binary__393                   775.2
# num__528                      741.7
# binary__391                   714.7
# num__missingindicator_134     706.3
# num__missingindicator_141     599.3
# num__409                      587.3
# binary__395                   548.3
# num__missingindicator_122     500.8
# dtype: float64
#
# --- life_situation ---
# binary__391                  1922.0
# num__missingindicator_035    1922.0
# num__missingindicator_134    1800.0
# num__446                     1740.5
# binary__393                  1740.5
# num__missingindicator_141    1568.0
# binary__438                  1512.5
# num__003                     1512.5
# num__404                     1404.5
# num__missingindicator_140    1404.5
# num__missingindicator_528    1404.5
# num__409                     1200.5
# binary__390                  1152.0
# num__289                     1152.0
# binary__395                  1104.5
# dtype: float64
#
# --- education_group ---
# binary__390                  903.619048
# num__402                     889.142857
# num__missingindicator_035    884.619048
# binary__391                  861.476190
# num__404                     819.285714
# binary__400                  783.476190
# num__141                     764.571429
# binary__393                  708.952381
# binary__401                  704.285714
# num__405                     630.904762
# num__003                     620.238095
# num__409                     613.285714
# num__005                     573.285714
# num__446                     515.000000
# binary__395                  494.142857
# dtype: float64
#
# ================================================================================
# RANK VARIANCE (TOP 15 COMMON FEATURES) — Regime C
# ================================================================================
#
# --- age_group ---
# num__missingindicator_035    1261.000000
# binary__391                  1261.000000
# num__003                     1241.333333
# num__446                     1161.333333
# num__missingindicator_405    1160.333333
# num__missingindicator_136     973.000000
# binary__401                   921.000000
# binary__399                   901.333333
# binary__390                   876.000000
# binary__400                   849.000000
# binary__395                   829.000000
# num__missingindicator_409     727.000000
# binary__437                   723.000000
# num__409                      692.333333
# num__141                      690.333333
# dtype: float64
#
# --- sector_group ---
# num__402                     1134.8
# num__missingindicator_035    1063.2
# num__141                      782.0
# binary__391                   775.2
# num__003                      758.3
# num__136                      664.3
# binary__401                   648.7
# binary__395                   642.0
# binary__400                   617.2
# binary__390                   582.8
# binary__396                   568.8
# num__005                      564.7
# num__missingindicator_136     537.8
# num__409                      514.7
# binary__393                   502.3
# dtype: float64
#
# --- life_situation ---
# binary__391                  1922.0
# num__missingindicator_035    1922.0
# num__missingindicator_405    1800.0
# num__446                     1800.0
# binary__393                  1568.0
# num__missingindicator_136    1568.0
# binary__399                  1568.0
# num__409                     1512.5
# num__missingindicator_409    1352.0
# binary__390                  1352.0
# binary__400                  1200.5
# binary__392                   968.0
# num__450                      882.0
# binary__396                   840.5
# binary__437                   760.5
# dtype: float64
#
# --- education_group ---
# num__003                     898.142857
# binary__390                  834.476190
# binary__400                  827.571429
# num__missingindicator_035    821.952381
# num__402                     818.904762
# num__409                     798.285714
# binary__391                  793.904762
# num__143                     715.285714
# binary__393                  696.571429
# num__141                     669.571429
# num__005                     668.238095
# num__404                     639.285714
# binary__401                  612.000000
# binary__396                  571.952381
# num__missingindicator_405    568.238095
# dtype: float64

# %%
cross_regime_stability = {}

for subgroup in all_subgroup_results["Regime A"]["rank_variance_common"].keys():
    df = pd.DataFrame({
        regime_name: results["rank_variance_common"][subgroup]
        for regime_name, results in all_subgroup_results.items()
    })

    # Select top 15 features by average variance across regimes
    top_features = (
        df.mean(axis=1)
        .sort_values(ascending=False)
        .head(TOP_N)
        .index
    )

    cross_regime_stability[subgroup] = df.loc[top_features]

# Print them
for subgroup, df in cross_regime_stability.items():
    print("\n" + "="*80)
    print(f"CROSS‑REGIME SUBGROUP STABILITY (TOP {TOP_N}) — {subgroup}")
    print("="*80)
    print(df)
# Out:
# ================================================================================
# CROSS‑REGIME SUBGROUP STABILITY (TOP 15) — age_group
# ================================================================================
#                               Regime A     Regime B     Regime C
# binary__391                1281.333333  1261.000000  1261.000000
# num__missingindicator_035  1143.000000  1281.333333  1261.000000
# num__003                   1026.333333  1240.333333  1241.333333
# num__446                   1161.333333  1066.333333  1161.333333
# binary__401                 984.333333  1012.333333   921.000000
# binary__400                 903.000000   917.333333   849.000000
# binary__399                 937.333333   817.000000   901.333333
# binary__393                1017.333333  1121.333333   489.000000
# binary__390                 829.000000   850.333333   876.000000
# binary__395                 867.000000   684.333333   829.000000
# num__409                   1029.000000   641.333333   692.333333
# num__missingindicator_405   625.333333   448.000000  1160.333333
# num__404                    940.333333   956.333333   111.000000
# num__missingindicator_136   296.333333   691.000000   973.000000
# binary__438                 871.000000   960.333333   121.000000
#
# ================================================================================
# CROSS‑REGIME SUBGROUP STABILITY (TOP 15) — sector_group
# ================================================================================
#                            Regime A  Regime B  Regime C
# num__402                     1116.8    1153.2    1134.8
# num__missingindicator_035     763.5    1068.7    1063.2
# num__141                      920.5     867.5     782.0
# num__404                      915.2     856.8     471.7
# binary__391                   697.7     714.7     775.2
# binary__401                   709.5     829.3     648.7
# binary__390                   713.3     860.7     582.8
# binary__400                   687.8     813.2     617.2
# num__409                      757.3     587.3     514.7
# num__003                      509.8     436.5     758.3
# binary__393                   416.7     775.2     502.3
# num__136                      652.3     377.3     664.3
# binary__395                   451.5     548.3     642.0
# num__122                      644.0     497.7     479.7
# num__005                      542.7     475.3     564.7
#
# ================================================================================
# CROSS‑REGIME SUBGROUP STABILITY (TOP 15) — life_situation
# ================================================================================
#                            Regime A  Regime B  Regime C
# binary__391                  1922.0    1922.0    1922.0
# num__missingindicator_035    1860.5    1922.0    1922.0
# num__446                     1800.0    1740.5    1800.0
# binary__393                  1624.5    1740.5    1568.0
# num__409                     1624.5    1200.5    1512.5
# num__missingindicator_405    1104.5     648.0    1800.0
# binary__399                  1250.0     684.5    1568.0
# num__404                     1458.0    1404.5     578.0
# binary__438                  1568.0    1512.5     312.5
# num__missingindicator_140    1300.5    1404.5     512.0
# num__missingindicator_136     612.5    1012.5    1568.0
# binary__390                   578.0    1152.0    1352.0
# num__003                     1058.0    1512.5     450.0
# num__289                      968.0    1152.0     544.5
# num__missingindicator_134     180.5    1800.0     648.0
#
# ================================================================================
# CROSS‑REGIME SUBGROUP STABILITY (TOP 15) — education_group
# ================================================================================
#                              Regime A    Regime B    Regime C
# binary__390                861.238095  903.619048  834.476190
# num__402                   838.142857  889.142857  818.904762
# binary__391                837.904762  861.476190  793.904762
# num__404                   882.285714  819.285714  639.285714
# num__missingindicator_035  560.476190  884.619048  821.952381
# num__409                   819.904762  613.285714  798.285714
# binary__400                586.952381  783.476190  827.571429
# num__141                   754.000000  764.571429  669.571429
# num__003                   582.952381  620.238095  898.142857
# binary__393                604.142857  708.952381  696.571429
# binary__401                680.000000  704.285714  612.000000
# num__005                   556.809524  573.285714  668.238095
# num__143                   371.238095  493.952381  715.285714
# num__446                   663.809524  515.000000  365.666667
# num__405                   543.476190  630.904762  300.952381

# %%
all_subgroup_results_readable = {}

for regime_name, results in all_subgroup_results.items():

    readable_profiles = {
        subgroup: rename_features(profile, feature_name_map)
        for subgroup, profile in results["subgroup_profiles_common"].items()
    }

    readable_rank_var = {
        subgroup: rename_features(rank_var.to_frame("Rank Variance"), feature_name_map)
        for subgroup, rank_var in results["rank_variance_common"].items()
    }

    all_subgroup_results_readable[regime_name] = {
        "subgroup_profiles_common": readable_profiles,
        "rank_variance_common": readable_rank_var
    }

# %%
cross_regime_stability_readable = {}

for subgroup, df in cross_regime_stability.items():
    cross_regime_stability_readable[subgroup] = rename_features(df, feature_name_map)

# %%
TOP_N = 15

for regime_name, results in all_subgroup_results_readable.items():
    print("\n" + "="*80)
    print(f"SUBGROUP PROFILES (TOP {TOP_N}) — {regime_name}")
    print("="*80)

    for subgroup, profile in results["subgroup_profiles_common"].items():
        top_features = (
            profile.mean(axis=1)
            .sort_values(ascending=False)
            .head(TOP_N)
            .index
        )
        print(f"\n--- {subgroup} ---")
        print(profile.loc[top_features])
# Out:
# ================================================================================
# SUBGROUP PROFILES (TOP 15) — Regime A
# ================================================================================
#
# --- age_group ---
# age_group                           Young  Mid-career     Older
# Reason <36h: family situation    0.516676   -0.564752  0.497493
# Works less to care for children  0.150671   -0.169026  0.201789
# No children or grandchildren     0.201821   -0.019569 -0.051261
# Retirement feeling               0.075291    0.024439  0.000813
# Reason <36h: disability          0.103446    0.029012 -0.059795
# Does household work              0.038004   -0.020764  0.051969
# Has children under age 8         0.018377   -0.041049  0.078891
# Has children                     0.056653   -0.004620 -0.005535
# Reason <36h: family/health       0.028220    0.015769  0.000402
# Evening work frequency          -0.029221    0.033584  0.035021
# Sector                          -0.058572    0.115318 -0.019662
# Does voluntary work              0.033203   -0.002239  0.002574
# Stopped working age              0.019520    0.003798  0.006304
# Expected retirement age          0.123824    0.056010 -0.150292
# Weekend work frequency           0.074568   -0.042103 -0.011668
#
# --- sector_group ---
# sector_group                              Agriculture & Extraction  \
# Sector                                                    1.537706
# Supervises employees                                      0.877860
# Reason <36h: family situation                             0.885324
# Reason <36h: other                                        0.719667
# Weekend work frequency                                    0.894016
# Retirement feeling                                        0.308337
# Occupation (first job)                                    0.631634
# Missing: organisation type (current job)                  0.615173
# Evening work frequency                                    0.459698
# Works less to care for children                           0.227848
# Missing: evening work frequency                           0.129928
# Missing: evening work frequency                           0.002615
# Missing: occupation (first job)                           0.041964
# Reason <36h: no opportunity to work more                  0.120516
# Reason <36h: health                                       0.277661
# Reason <36h: other activities                             0.169455
#
# sector_group                              Culture & Other Services  \
# Sector                                                   -0.252765
# Supervises employees                                     -0.073125
# Reason <36h: family situation                             0.130664
# Reason <36h: other                                       -0.322985
# Weekend work frequency                                    0.038601
# Retirement feeling                                        0.155620
# Occupation (first job)                                   -0.006184
# Missing: organisation type (current job)                  0.018449
# Evening work frequency                                    0.007426
# Works less to care for children                           0.026962
# Missing: evening work frequency                          -0.003527
# Missing: evening work frequency                          -0.002435
# Missing: occupation (first job)                           0.012482
# Reason <36h: no opportunity to work more                 -0.138357
# Reason <36h: health                                      -0.000740
# Reason <36h: other activities                            -0.027663
#
# sector_group                              Production & Construction  \
# Sector                                                     1.292933
# Supervises employees                                       0.450451
# Reason <36h: family situation                              0.592843
# Reason <36h: other                                         0.430664
# Weekend work frequency                                    -0.202349
# Retirement feeling                                         0.276847
# Occupation (first job)                                     0.123201
# Missing: organisation type (current job)                  -0.030638
# Evening work frequency                                     0.006142
# Works less to care for children                            0.162070
# Missing: evening work frequency                            0.063242
# Missing: evening work frequency                            0.002890
# Missing: occupation (first job)                            0.080708
# Reason <36h: no opportunity to work more                   0.373780
# Reason <36h: health                                        0.051522
# Reason <36h: other activities                              0.141435
#
# sector_group                              Public & Social Services  \
# Sector                                                   -0.650916
# Supervises employees                                     -0.126122
# Reason <36h: family situation                            -0.531876
# Reason <36h: other                                       -0.003968
# Weekend work frequency                                   -0.053059
# Retirement feeling                                       -0.279607
# Occupation (first job)                                   -0.053618
# Missing: organisation type (current job)                 -0.045429
# Evening work frequency                                    0.009908
# Works less to care for children                          -0.050075
# Missing: evening work frequency                           0.032634
# Missing: evening work frequency                           0.001999
# Missing: occupation (first job)                           0.057729
# Reason <36h: no opportunity to work more                 -0.202689
# Reason <36h: health                                      -0.205880
# Reason <36h: other activities                            -0.024006
#
# sector_group                              Trade & Market Services
# Sector                                                   0.489770
# Supervises employees                                     0.046389
# Reason <36h: family situation                            0.062416
# Reason <36h: other                                      -0.034812
# Weekend work frequency                                   0.085304
# Retirement feeling                                       0.224416
# Occupation (first job)                                  -0.047639
# Missing: organisation type (current job)                 0.001185
# Evening work frequency                                   0.026999
# Works less to care for children                         -0.056583
# Missing: evening work frequency                         -0.001392
# Missing: evening work frequency                         -0.001136
# Missing: occupation (first job)                          0.015524
# Reason <36h: no opportunity to work more                 0.046125
# Reason <36h: health                                      0.071303
# Reason <36h: other activities                           -0.067943
#
# --- life_situation ---
# life_situation                       None  Provides care
# Reason <36h: family situation    0.973622      -0.590496
# Works less to care for children  0.294131      -0.155225
# No children or grandchildren     0.229307      -0.108697
# Sector                           0.044039       0.048375
# Reason <36h: home activities     0.223810      -0.153716
# Retirement feeling               0.050585       0.015002
# Has children under age 8         0.069590      -0.026885
# Evening work frequency          -0.008571       0.042885
# Has children                     0.052167      -0.019289
# Reason <36h: family/health       0.028182       0.003402
# Reason <36h: partial retirement  0.061276      -0.030630
# Does household work              0.035101      -0.005510
# Expected retirement age          0.063961      -0.034959
# Age                              0.064601      -0.039754
# Provides informal care           0.045534      -0.021988
#
# --- education_group ---
# education_group                           Agriculture  Arts_Humanities  \
# Supervises employees                         0.718973        -0.027043
# Evening work frequency                       0.344369         0.031548
# Sector                                       0.647846        -0.279235
# Weekend work frequency                       0.422635         0.111916
# Reason <36h: other                           0.628004        -0.644662
# Occupation (first job)                       0.511154        -0.071136
# Reason <36h: family situation                0.630326         0.024635
# Retirement feeling                           0.155581        -0.081425
# Missing: occupation (first job)              0.026741         0.002645
# Missing: organisation type (current job)     0.260722         0.005756
# Reason <36h: home activities                 0.349817         0.044430
# Missing: evening work frequency              0.051214         0.054291
# Missing: evening work frequency              0.002283        -0.000708
# Works less to care for children              0.217061        -0.033430
# Does household work                          0.097439        -0.028619
# Reason <36h: other activities                0.164667        -0.037184
#
# education_group                           Business_Law  Education  \
# Supervises employees                          0.222410  -0.351703
# Evening work frequency                       -0.064585  -0.067972
# Sector                                        0.156500   0.090055
# Weekend work frequency                       -0.132638  -0.037473
# Reason <36h: other                            0.149290  -0.063109
# Occupation (first job)                       -0.107424  -0.076214
# Reason <36h: family situation                -0.333025  -0.120612
# Retirement feeling                            0.056108   0.012110
# Missing: occupation (first job)               0.038080  -0.021709
# Missing: organisation type (current job)     -0.004283  -0.004864
# Reason <36h: home activities                  0.100210  -0.196426
# Missing: evening work frequency               0.099397  -0.012417
# Missing: evening work frequency               0.001130  -0.002281
# Works less to care for children              -0.135172   0.020362
# Does household work                           0.009930  -0.052930
# Reason <36h: other activities                -0.009023  -0.102005
#
# education_group                           Health_Care      STEM  Services
# Supervises employees                        -0.227093  0.171563  0.285858
# Evening work frequency                      -0.000059  0.070934  0.385097
# Sector                                      -0.720304  0.457988  0.333742
# Weekend work frequency                       0.031898 -0.035594  0.300357
# Reason <36h: other                          -0.076650  0.138925  0.246722
# Occupation (first job)                      -0.075730  0.133802  0.045147
# Reason <36h: family situation               -0.936718  0.801561  0.203280
# Retirement feeling                          -0.104294  0.127207  0.068134
# Missing: occupation (first job)              0.038301  0.038745  0.070260
# Missing: organisation type (current job)    -0.026287 -0.026578 -0.030013
# Reason <36h: home activities                -0.496462  0.284534  0.066113
# Missing: evening work frequency             -0.058270  0.032898 -0.018030
# Missing: evening work frequency              0.000731  0.001053  0.003050
# Works less to care for children             -0.092156  0.176408 -0.004770
# Does household work                         -0.068300  0.098439  0.091556
# Reason <36h: other activities               -0.030403  0.059435  0.097629
#
# ================================================================================
# SUBGROUP PROFILES (TOP 15) — Regime B
# ================================================================================
#
# --- age_group ---
# age_group                            Young  Mid-career     Older
# Reason <36h: family situation     0.350199   -0.401814  0.298434
# Sector                            0.038226    0.132388 -0.051416
# Workplace size                    0.019590    0.074328  0.023804
# Missing: occupation (first job)  -0.039673    0.056125  0.062933
# Reason <36h: disability           0.076264    0.045704 -0.045304
# Works less to care for children   0.117172   -0.143028  0.099182
# Missing: workplace size           0.051565   -0.006212  0.015901
# No children or grandchildren      0.152731   -0.031828 -0.065173
# Reason <36h: health               0.145990    0.021149 -0.122782
# Missing: supervises employees    -0.054924    0.048718  0.048850
# Missing: provides informal care   0.027884    0.003306  0.009976
# Education completed (2nd degree)  0.053792    0.033492 -0.059919
# Commute to work (minutes)        -0.017521    0.071427 -0.027910
# Reason <36h: partial retirement   0.042462    0.041610 -0.059495
# Year started working              0.027242   -0.017444  0.014288
#
# --- sector_group ---
# sector_group                              Agriculture & Extraction  \
# Sector                                                    1.874739
# Reason <36h: family situation                             0.480681
# Reason <36h: no opportunity to work more                  0.483369
# Supervises employees                                      0.378751
# Has sideline job                                          0.153554
# Reason <36h: home activities                              0.351794
# Reason <36h: more leisure                                 0.233432
# Reason <36h: other activities                             0.102852
# Evening work frequency                                    0.241500
# Retirement feeling                                        0.068086
# Weekend work frequency                                    0.224153
# Missing: organisation type (current job)                  0.330743
# Reason <36h: disability                                   0.077024
# Missing: occupation (first job)                          -0.028016
# Works less to care for children                           0.096734
#
# sector_group                              Culture & Other Services  \
# Sector                                                   -0.578929
# Reason <36h: family situation                             0.124039
# Reason <36h: no opportunity to work more                 -0.067137
# Supervises employees                                     -0.014879
# Has sideline job                                          0.012027
# Reason <36h: home activities                             -0.107577
# Reason <36h: more leisure                                 0.018833
# Reason <36h: other activities                             0.052289
# Evening work frequency                                   -0.008105
# Retirement feeling                                        0.038816
# Weekend work frequency                                    0.105847
# Missing: organisation type (current job)                 -0.028658
# Reason <36h: disability                                   0.038153
# Missing: occupation (first job)                           0.036338
# Works less to care for children                           0.014259
#
# sector_group                              Production & Construction  \
# Sector                                                     1.261254
# Reason <36h: family situation                              0.521537
# Reason <36h: no opportunity to work more                   0.623750
# Supervises employees                                       0.137042
# Has sideline job                                           0.173463
# Reason <36h: home activities                               0.311024
# Reason <36h: more leisure                                  0.278301
# Reason <36h: other activities                              0.056390
# Evening work frequency                                    -0.012879
# Retirement feeling                                         0.151027
# Weekend work frequency                                    -0.132714
# Missing: organisation type (current job)                  -0.052919
# Reason <36h: disability                                    0.000891
# Missing: occupation (first job)                            0.062801
# Works less to care for children                            0.068917
#
# sector_group                              Public & Social Services  \
# Sector                                                   -0.698144
# Reason <36h: family situation                            -0.362401
# Reason <36h: no opportunity to work more                 -0.269348
# Supervises employees                                     -0.131434
# Has sideline job                                         -0.043537
# Reason <36h: home activities                             -0.243203
# Reason <36h: more leisure                                -0.261114
# Reason <36h: other activities                            -0.014412
# Evening work frequency                                   -0.016454
# Retirement feeling                                       -0.171885
# Weekend work frequency                                   -0.088076
# Missing: organisation type (current job)                 -0.038991
# Reason <36h: disability                                  -0.010701
# Missing: occupation (first job)                           0.057056
# Works less to care for children                          -0.054970
#
# sector_group                              Trade & Market Services
# Sector                                                   0.802793
# Reason <36h: family situation                            0.156694
# Reason <36h: no opportunity to work more                 0.019974
# Supervises employees                                     0.065509
# Has sideline job                                         0.036333
# Reason <36h: home activities                            -0.012658
# Reason <36h: more leisure                               -0.044926
# Reason <36h: other activities                            0.015196
# Evening work frequency                                   0.000755
# Retirement feeling                                       0.107674
# Weekend work frequency                                   0.071191
# Missing: organisation type (current job)                -0.038943
# Reason <36h: disability                                  0.054040
# Missing: occupation (first job)                          0.017827
# Works less to care for children                          0.019000
#
# --- life_situation ---
# life_situation                        None  Provides care
# Reason <36h: family situation     0.756424      -0.474137
# Sector                            0.107293       0.007732
# Workplace size                    0.047492       0.042688
# Works less to care for children   0.199237      -0.130274
# Missing: occupation (first job)  -0.002443       0.063886
# No children or grandchildren      0.163751      -0.112107
# Reason <36h: disability           0.036806       0.009168
# Missing: supervises employees    -0.016140       0.053855
# Commute to work (minutes)         0.026957       0.010501
# Has sideline job                  0.007073       0.026358
# Missing: evening work frequency  -0.054158       0.079512
# Missing: evening work frequency  -0.041640       0.050285
# Reason <36h: other activities    -0.011978       0.036966
# Education completed (2nd degree)  0.041812      -0.019233
# Age                               0.145447      -0.124832
# Reason <36h: health               0.068924      -0.049402
#
# --- education_group ---
# education_group                     Agriculture  Arts_Humanities  \
# Sector                                 0.637352        -0.248663
# Missing: occupation (first job)        0.069721         0.038528
# Weekend work frequency                 0.140978         0.056868
# Workplace size                         0.029966         0.044550
# Missing: weekend work frequency        0.081718         0.018735
# Reason <36h: disability                0.078077         0.077892
# Missing: supervises employees          0.056575         0.022384
# Missing: year started working          0.126354         0.008299
# Missing: evening work frequency        0.127642         0.070632
# Missing: evening work frequency        0.044188         0.011122
# Commute to work (minutes)              0.112744         0.119050
# Missing: commute to work (minutes)     0.065018         0.019388
# Reason <36h: other activities          0.047273        -0.080334
# Missing: evening work frequency        0.127642         0.070632
# Missing: evening work frequency        0.044188         0.011122
# Supervises employees                   0.316202         0.067870
# Reason <36h: other                     0.320571        -0.160002
#
# education_group                     Business_Law  Education  Health_Care  \
# Sector                                  0.292209   0.157714    -1.039961
# Missing: occupation (first job)         0.042187  -0.000064     0.046878
# Weekend work frequency                 -0.087943  -0.080250     0.048180
# Workplace size                          0.107277   0.006238    -0.064404
# Missing: weekend work frequency         0.060017  -0.085179     0.051187
# Reason <36h: disability                 0.044339  -0.039365     0.015146
# Missing: supervises employees           0.033516  -0.012113     0.032999
# Missing: year started working           0.053490  -0.175563     0.050254
# Missing: evening work frequency         0.117610  -0.048215    -0.039282
# Missing: evening work frequency         0.027618  -0.039982     0.025983
# Commute to work (minutes)               0.035393  -0.097630    -0.095652
# Missing: commute to work (minutes)      0.034321  -0.047093     0.031845
# Reason <36h: other activities           0.051640  -0.008615     0.016625
# Missing: evening work frequency         0.117610  -0.048215    -0.039282
# Missing: evening work frequency         0.027618  -0.039982     0.025983
# Supervises employees                    0.138231  -0.244067    -0.285811
# Reason <36h: other                      0.161949  -0.352743    -0.047848
#
# education_group                         STEM  Services
# Sector                              0.427403  0.529868
# Missing: occupation (first job)     0.044917  0.060098
# Weekend work frequency             -0.009512  0.199968
# Workplace size                      0.080852  0.063106
# Missing: weekend work frequency     0.047699  0.090963
# Reason <36h: disability             0.009000  0.033825
# Missing: supervises employees       0.035400  0.046346
# Missing: year started working       0.040894  0.109761
# Missing: evening work frequency     0.030386 -0.058907
# Missing: evening work frequency     0.022419  0.042516
# Commute to work (minutes)           0.091940  0.028140
# Missing: commute to work (minutes)  0.031759  0.057514
# Reason <36h: other activities       0.027464  0.098771
# Missing: evening work frequency     0.030386 -0.058907
# Missing: evening work frequency     0.022419  0.042516
# Supervises employees                0.072546  0.068613
# Reason <36h: other                  0.063044  0.143916
#
# ================================================================================
# SUBGROUP PROFILES (TOP 15) — Regime C
# ================================================================================
#
# --- age_group ---
# age_group                           Young  Mid-career     Older
# Commute to work (minutes)        0.104260    0.083839  0.002228
# Reason <36h: partial retirement  0.069736    0.064194 -0.018076
# Highest Dutch education          0.036230    0.091763 -0.015242
# Missing: evening work frequency -0.022706    0.009397  0.007787
# Missing: evening work frequency  0.106476    0.000278  0.003593
# Sector                          -0.005941    0.026932  0.082664
# Reason <36h: home activities     0.076725    0.036931 -0.015303
# Workplace size                   0.027787    0.030062  0.023129
# Year started working             0.003331    0.014695  0.048086
# num__missingindicator_288        0.004522    0.014518  0.043253
# num__142                         0.034327    0.009077  0.007014
# Has taken job courses            0.048316    0.023738 -0.024804
# Missing: weekend work frequency  0.016678    0.011085  0.012717
# Has grandchildren                0.053468    0.047097 -0.064073
# Expected retirement age          0.032196    0.028212 -0.027428
# Supervises employees            -0.077289    0.050868  0.058780
#
# --- sector_group ---
# sector_group                     Agriculture & Extraction  \
# Sector                                           1.169996
# Supervises employees                             0.474060
# Missing: occupation (first job)                  0.237516
# Reason <36h: more leisure                        0.552503
# Reason <36h: home activities                     0.317137
# Reason <36h: family situation                    0.356239
# Missing: supervises employees                    0.081734
# Reason <36h: partial retirement                  0.075500
# Year started working                             0.126334
# Weekend work frequency                           0.291489
# Commute to work (minutes)                       -0.032989
# Reason <36h: other                               0.141036
# Workplace size                                   0.095912
# Retirement feeling                               0.021100
# Occupation (first job)                           0.093164
#
# sector_group                     Culture & Other Services  \
# Sector                                          -0.283702
# Supervises employees                             0.125395
# Missing: occupation (first job)                  0.049235
# Reason <36h: more leisure                        0.038830
# Reason <36h: home activities                     0.022848
# Reason <36h: family situation                   -0.031616
# Missing: supervises employees                    0.029155
# Reason <36h: partial retirement                  0.032784
# Year started working                             0.037210
# Weekend work frequency                           0.020857
# Commute to work (minutes)                       -0.029723
# Reason <36h: other                              -0.178715
# Workplace size                                  -0.034906
# Retirement feeling                               0.061432
# Occupation (first job)                           0.007084
#
# sector_group                     Production & Construction  \
# Sector                                            1.244405
# Supervises employees                              0.181731
# Missing: occupation (first job)                   0.228011
# Reason <36h: more leisure                         0.221257
# Reason <36h: home activities                      0.188313
# Reason <36h: family situation                     0.448456
# Missing: supervises employees                     0.074149
# Reason <36h: partial retirement                   0.080047
# Year started working                             -0.001900
# Weekend work frequency                           -0.126755
# Commute to work (minutes)                         0.149133
# Reason <36h: other                                0.311845
# Workplace size                                    0.024366
# Retirement feeling                                0.104467
# Occupation (first job)                            0.050317
#
# sector_group                     Public & Social Services  \
# Sector                                          -0.504784
# Supervises employees                            -0.101344
# Missing: occupation (first job)                  0.249145
# Reason <36h: more leisure                       -0.360358
# Reason <36h: home activities                    -0.124422
# Reason <36h: family situation                   -0.492971
# Missing: supervises employees                    0.078658
# Reason <36h: partial retirement                  0.020826
# Year started working                             0.010521
# Weekend work frequency                          -0.090534
# Commute to work (minutes)                        0.104738
# Reason <36h: other                              -0.113777
# Workplace size                                   0.034278
# Retirement feeling                              -0.121517
# Occupation (first job)                          -0.027700
#
# sector_group                     Trade & Market Services
# Sector                                          0.406530
# Supervises employees                            0.185900
# Missing: occupation (first job)                 0.060097
# Reason <36h: more leisure                       0.041240
# Reason <36h: home activities                    0.088265
# Reason <36h: family situation                   0.030069
# Missing: supervises employees                   0.028309
# Reason <36h: partial retirement                 0.012677
# Year started working                            0.045251
# Weekend work frequency                          0.089000
# Commute to work (minutes)                      -0.017930
# Reason <36h: other                              0.011088
# Workplace size                                  0.033459
# Retirement feeling                              0.086719
# Occupation (first job)                          0.009351
#
# --- life_situation ---
# life_situation                       None  Provides care
# Commute to work (minutes)        0.069141       0.045652
# Reason <36h: home activities     0.175440      -0.074979
# Sector                           0.046907       0.040659
# Highest Dutch education          0.048392       0.031348
# Reason <36h: partial retirement  0.066451       0.009939
# Reason <36h: family situation    0.586128      -0.523539
# Works less to care for children  0.232123      -0.170161
# Missing: evening work frequency -0.011329       0.011481
# Missing: evening work frequency  0.056938      -0.000368
# Year started working             0.028383       0.024954
# Workplace size                   0.025456       0.027499
# num__missingindicator_288        0.014876       0.030159
# Reason <36h: other activities    0.008909       0.019819
# num__142                         0.017875       0.010058
# Missing: weekend work frequency  0.015260       0.011294
# Stopped working age              0.009644       0.016510
#
# --- education_group ---
# education_group                  Agriculture  Arts_Humanities  Business_Law  \
# Commute to work (minutes)           0.001919         0.159444      0.054805
# Missing: occupation (first job)    -0.123144         0.008275      0.143498
# Supervises employees                0.100873        -0.087670      0.151851
# Reason <36h: partial retirement     0.066770         0.074890     -0.008009
# Workplace size                     -0.006467         0.053705      0.046459
# num__142                            0.069860        -0.023399     -0.042614
# Sector                              0.203057        -0.149575      0.126174
# Year started working                0.059991        -0.005116      0.039872
# Missing: evening work frequency     0.009437         0.014864      0.015809
# Missing: evening work frequency     0.072421         0.025839      0.015950
# num__missingindicator_288           0.035663         0.019133      0.020815
# Missing: supervises employees      -0.004821         0.011668      0.056018
# Highest Dutch education            -0.129113         0.230735      0.097159
# Evening work frequency              0.111328        -0.016407     -0.013571
# Reason <36h: home activities        0.143075        -0.050598      0.115303
# Stopped working age                -0.016485         0.009338      0.004804
#
# education_group                  Education  Health_Care      STEM  Services
# Commute to work (minutes)        -0.039289     0.027472  0.070101  0.110119
# Missing: occupation (first job)  -0.089945     0.135924  0.075338  0.191539
# Supervises employees             -0.171158    -0.160864  0.101534  0.402082
# Reason <36h: partial retirement   0.048588     0.005384  0.041352  0.071085
# Workplace size                    0.014985     0.012029  0.007003  0.072692
# num__142                          0.058694     0.069694  0.005308  0.057944
# Sector                           -0.030721    -0.515438  0.335727  0.224752
# Year started working              0.015738     0.030389  0.028299  0.021984
# Missing: evening work frequency  -0.005481     0.000655 -0.002113 -0.029990
# Missing: evening work frequency   0.047367     0.005915  0.018776  0.003057
# num__missingindicator_288         0.028394     0.021793  0.026223  0.028517
# Missing: supervises employees    -0.010212     0.034025  0.030985  0.056177
# Highest Dutch education          -0.129549     0.035787  0.027474 -0.016688
# Evening work frequency           -0.064340     0.040779  0.021999  0.034755
# Reason <36h: home activities     -0.141528    -0.190590  0.147951  0.082246
# Stopped working age               0.018408     0.037598  0.006071  0.039727

# %%
for regime_name, results in all_subgroup_results_readable.items():
    print("\n" + "="*80)
    print(f"RANK VARIANCE (TOP {TOP_N}) — {regime_name}")
    print("="*80)

    for subgroup, rank_var in results["rank_variance_common"].items():
        print(f"\n--- {subgroup} ---")
        print(rank_var.head(TOP_N))
# Out:
# ================================================================================
# RANK VARIANCE (TOP 15) — Regime A
# ================================================================================
#
# --- age_group ---
#                                           Rank Variance
# Reason <36h: family situation               1281.333333
# Works less to care for children             1161.333333
# Missing: took job courses                   1143.000000
# Is student with expense claim               1102.333333
# Supervises employees                        1029.000000
# Age                                         1026.333333
# Reason <36h: home activities                1017.333333
# Reason <36h: other                           984.333333
# Occupation (current job)                     940.333333
# Reason <36h: take it easier                  937.333333
# Reason <36h: more leisure                    903.000000
# No children or grandchildren                 871.000000
# Reason <36h: health                          867.000000
# Reason <36h: no opportunity to work more     829.000000
# Expected retirement age                      758.333333
#
# --- sector_group ---
#                                            Rank Variance
# Sector                                            1116.8
# Weekend work frequency                             920.5
# Occupation (current job)                           915.2
# Missing: took job courses                          763.5
# Supervises employees                               757.3
# Reason <36h: no opportunity to work more           713.3
# Reason <36h: other                                 709.5
# Reason <36h: family situation                      697.7
# Reason <36h: more leisure                          687.8
# Commute to work (minutes)                          652.3
# Retirement feeling                                 644.0
# Works less to care for children                    639.5
# Is student with expense claim                      623.8
# Education completed (2nd degree)                   597.3
# Missing: option to continue after pension          585.7
#
# --- life_situation ---
#                                            Rank Variance
# Reason <36h: family situation                     1922.0
# Missing: took job courses                         1860.5
# Works less to care for children                   1800.0
# Reason <36h: other                                1800.0
# Is student with expense claim                     1682.0
# Supervises employees                              1624.5
# Reason <36h: home activities                      1624.5
# No children or grandchildren                      1568.0
# Occupation (current job)                          1458.0
# Education completed (2nd degree)                  1352.0
# Missing: option to continue after pension         1300.5
# Missing: evening work frequency                   1300.5
# Reason <36h: take it easier                       1250.0
# Missing: occupation (first job)                   1104.5
# Age                                               1058.0
#
# --- education_group ---
#                                           Rank Variance
# Occupation (current job)                     882.285714
# Reason <36h: no opportunity to work more     861.238095
# Sector                                       838.142857
# Reason <36h: family situation                837.904762
# Supervises employees                         819.904762
# Weekend work frequency                       754.000000
# Reason <36h: partial retirement              699.285714
# Reason <36h: other                           680.000000
# Education completed (2nd degree)             677.238095
# Works less to care for children              663.809524
# Reason <36h: home activities                 604.142857
# Commute to work (minutes)                    599.238095
# Reason <36h: more leisure                    586.952381
# Age                                          582.952381
# Missing: took job courses                    560.476190
#
# ================================================================================
# RANK VARIANCE (TOP 15) — Regime B
# ================================================================================
#
# --- age_group ---
#                                           Rank Variance
# Missing: took job courses                   1281.333333
# Reason <36h: family situation               1261.000000
# Age                                         1240.333333
# Missing: year started working               1141.000000
# Reason <36h: home activities                1121.333333
# Works less to care for children             1066.333333
# Reason <36h: other                          1012.333333
# No children or grandchildren                 960.333333
# Occupation (current job)                     956.333333
# Missing: weekend work frequency              937.333333
# Reason <36h: more leisure                    917.333333
# Reason <36h: no opportunity to work more     850.333333
# Reason <36h: take it easier                  817.000000
# Missing: evening work frequency              764.333333
# Missing: commute to work (minutes)           691.000000
#
# --- sector_group ---
#                                           Rank Variance
# Sector                                           1153.2
# Missing: took job courses                        1068.7
# Weekend work frequency                            867.5
# Reason <36h: no opportunity to work more          860.7
# Occupation (current job)                          856.8
# Reason <36h: other                                829.3
# Reason <36h: more leisure                         813.2
# Reason <36h: home activities                      775.2
# Workplace size                                    741.7
# Reason <36h: family situation                     714.7
# Missing: year started working                     706.3
# Missing: weekend work frequency                   599.3
# Supervises employees                              587.3
# Reason <36h: health                               548.3
# Missing: organisation type (current job)          500.8
#
# --- life_situation ---
#                                           Rank Variance
# Reason <36h: family situation                    1922.0
# Missing: took job courses                        1922.0
# Missing: year started working                    1800.0
# Works less to care for children                  1740.5
# Reason <36h: home activities                     1740.5
# Missing: weekend work frequency                  1568.0
# No children or grandchildren                     1512.5
# Age                                              1512.5
# Occupation (current job)                         1404.5
# Missing: evening work frequency                  1404.5
# Missing: workplace size                          1404.5
# Supervises employees                             1200.5
# Reason <36h: no opportunity to work more         1152.0
# Expected retirement age                          1152.0
# Reason <36h: health                              1104.5
#
# --- education_group ---
#                                           Rank Variance
# Reason <36h: no opportunity to work more     903.619048
# Sector                                       889.142857
# Missing: took job courses                    884.619048
# Reason <36h: family situation                861.476190
# Occupation (current job)                     819.285714
# Reason <36h: more leisure                    783.476190
# Weekend work frequency                       764.571429
# Reason <36h: home activities                 708.952381
# Reason <36h: other                           704.285714
# Occupation (first job)                       630.904762
# Age                                          620.238095
# Supervises employees                         613.285714
# Highest Dutch education                      573.285714
# Works less to care for children              515.000000
# Reason <36h: health                          494.142857
#
# ================================================================================
# RANK VARIANCE (TOP 15) — Regime C
# ================================================================================
#
# --- age_group ---
#                                           Rank Variance
# Missing: took job courses                   1261.000000
# Reason <36h: family situation               1261.000000
# Age                                         1241.333333
# Works less to care for children             1161.333333
# Missing: occupation (first job)             1160.333333
# Missing: commute to work (minutes)           973.000000
# Reason <36h: other                           921.000000
# Reason <36h: take it easier                  901.333333
# Reason <36h: no opportunity to work more     876.000000
# Reason <36h: more leisure                    849.000000
# Reason <36h: health                          829.000000
# Missing: supervises employees                727.000000
# Has grandchildren                            723.000000
# Supervises employees                         692.333333
# Weekend work frequency                       690.333333
#
# --- sector_group ---
#                                           Rank Variance
# Sector                                           1134.8
# Missing: took job courses                        1063.2
# Weekend work frequency                            782.0
# Reason <36h: family situation                     775.2
# Age                                               758.3
# Commute to work (minutes)                         664.3
# Reason <36h: other                                648.7
# Reason <36h: health                               642.0
# Reason <36h: more leisure                         617.2
# Reason <36h: no opportunity to work more          582.8
# Reason <36h: disability                           568.8
# Highest Dutch education                           564.7
# Missing: commute to work (minutes)                537.8
# Supervises employees                              514.7
# Reason <36h: home activities                      502.3
#
# --- life_situation ---
#                                           Rank Variance
# Reason <36h: family situation                    1922.0
# Missing: took job courses                        1922.0
# Missing: occupation (first job)                  1800.0
# Works less to care for children                  1800.0
# Reason <36h: home activities                     1568.0
# Missing: commute to work (minutes)               1568.0
# Reason <36h: take it easier                      1568.0
# Supervises employees                             1512.5
# Missing: supervises employees                    1352.0
# Reason <36h: no opportunity to work more         1352.0
# Reason <36h: more leisure                        1200.5
# Reason <36h: family/health                        968.0
# Provides informal care                            882.0
# Reason <36h: disability                           840.5
# Has grandchildren                                 760.5
#
# --- education_group ---
#                                           Rank Variance
# Age                                          898.142857
# Reason <36h: no opportunity to work more     834.476190
# Reason <36h: more leisure                    827.571429
# Missing: took job courses                    821.952381
# Sector                                       818.904762
# Supervises employees                         798.285714
# Reason <36h: family situation                793.904762
# Has sideline job                             715.285714
# Reason <36h: home activities                 696.571429
# Weekend work frequency                       669.571429
# Highest Dutch education                      668.238095
# Occupation (current job)                     639.285714
# Reason <36h: other                           612.000000
# Reason <36h: disability                      571.952381
# Missing: occupation (first job)              568.238095

# %%
for subgroup, df in cross_regime_stability_readable.items():
    top_features = (
        df.mean(axis=1)
        .sort_values(ascending=False)
        .head(TOP_N)
        .index
    )
    print("\n" + "="*80)
    print(f"CROSS‑REGIME STABILITY (TOP {TOP_N}) — {subgroup}")
    print("="*80)
    print(df.loc[top_features])
# Out:
# ================================================================================
# CROSS‑REGIME STABILITY (TOP 15) — age_group
# ================================================================================
#                                              Regime A     Regime B  \
# Reason <36h: family situation             1281.333333  1261.000000
# Missing: took job courses                 1143.000000  1281.333333
# Age                                       1026.333333  1240.333333
# Works less to care for children           1161.333333  1066.333333
# Reason <36h: other                         984.333333  1012.333333
# Reason <36h: more leisure                  903.000000   917.333333
# Reason <36h: take it easier                937.333333   817.000000
# Reason <36h: home activities              1017.333333  1121.333333
# Reason <36h: no opportunity to work more   829.000000   850.333333
# Reason <36h: health                        867.000000   684.333333
# Supervises employees                      1029.000000   641.333333
# Missing: occupation (first job)            625.333333   448.000000
# Occupation (current job)                   940.333333   956.333333
# Missing: commute to work (minutes)         296.333333   691.000000
# No children or grandchildren               871.000000   960.333333
#
#                                              Regime C
# Reason <36h: family situation             1261.000000
# Missing: took job courses                 1261.000000
# Age                                       1241.333333
# Works less to care for children           1161.333333
# Reason <36h: other                         921.000000
# Reason <36h: more leisure                  849.000000
# Reason <36h: take it easier                901.333333
# Reason <36h: home activities               489.000000
# Reason <36h: no opportunity to work more   876.000000
# Reason <36h: health                        829.000000
# Supervises employees                       692.333333
# Missing: occupation (first job)           1160.333333
# Occupation (current job)                   111.000000
# Missing: commute to work (minutes)         973.000000
# No children or grandchildren               121.000000
#
# ================================================================================
# CROSS‑REGIME STABILITY (TOP 15) — sector_group
# ================================================================================
#                                           Regime A  Regime B  Regime C
# Sector                                      1116.8    1153.2    1134.8
# Missing: took job courses                    763.5    1068.7    1063.2
# Weekend work frequency                       920.5     867.5     782.0
# Occupation (current job)                     915.2     856.8     471.7
# Reason <36h: family situation                697.7     714.7     775.2
# Reason <36h: other                           709.5     829.3     648.7
# Reason <36h: no opportunity to work more     713.3     860.7     582.8
# Reason <36h: more leisure                    687.8     813.2     617.2
# Supervises employees                         757.3     587.3     514.7
# Age                                          509.8     436.5     758.3
# Reason <36h: home activities                 416.7     775.2     502.3
# Commute to work (minutes)                    652.3     377.3     664.3
# Reason <36h: health                          451.5     548.3     642.0
# Retirement feeling                           644.0     497.7     479.7
# Highest Dutch education                      542.7     475.3     564.7
#
# ================================================================================
# CROSS‑REGIME STABILITY (TOP 15) — life_situation
# ================================================================================
#                                           Regime A  Regime B  Regime C
# Reason <36h: family situation               1922.0    1922.0    1922.0
# Missing: took job courses                   1860.5    1922.0    1922.0
# Works less to care for children             1800.0    1740.5    1800.0
# Reason <36h: home activities                1624.5    1740.5    1568.0
# Supervises employees                        1624.5    1200.5    1512.5
# Missing: occupation (first job)             1104.5     648.0    1800.0
# Reason <36h: take it easier                 1250.0     684.5    1568.0
# Occupation (current job)                    1458.0    1404.5     578.0
# No children or grandchildren                1568.0    1512.5     312.5
# Missing: evening work frequency             1300.5    1404.5     512.0
# Missing: commute to work (minutes)           612.5    1012.5    1568.0
# Reason <36h: no opportunity to work more     578.0    1152.0    1352.0
# Age                                         1058.0    1512.5     450.0
# Expected retirement age                      968.0    1152.0     544.5
# Missing: year started working                180.5    1800.0     648.0
#
# ================================================================================
# CROSS‑REGIME STABILITY (TOP 15) — education_group
# ================================================================================
#                                             Regime A    Regime B    Regime C
# Reason <36h: no opportunity to work more  861.238095  903.619048  834.476190
# Sector                                    838.142857  889.142857  818.904762
# Reason <36h: family situation             837.904762  861.476190  793.904762
# Occupation (current job)                  882.285714  819.285714  639.285714
# Missing: took job courses                 560.476190  884.619048  821.952381
# Supervises employees                      819.904762  613.285714  798.285714
# Reason <36h: more leisure                 586.952381  783.476190  827.571429
# Weekend work frequency                    754.000000  764.571429  669.571429
# Age                                       582.952381  620.238095  898.142857
# Reason <36h: home activities              604.142857  708.952381  696.571429
# Reason <36h: other                        680.000000  704.285714  612.000000
# Highest Dutch education                   556.809524  573.285714  668.238095
# Has sideline job                          371.238095  493.952381  715.285714
# Works less to care for children           663.809524  515.000000  365.666667
# Occupation (first job)                    543.476190  630.904762  300.952381
